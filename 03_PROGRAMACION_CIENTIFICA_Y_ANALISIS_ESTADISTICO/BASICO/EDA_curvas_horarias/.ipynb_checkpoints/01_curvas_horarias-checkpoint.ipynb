# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Curvas-horarias" data-toc-modified-id="Curvas-horarias-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Curvas horarias</a></span><ul class="toc-item"><li><span><a href="#Cargar-dato-de-contador" data-toc-modified-id="Cargar-dato-de-contador-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Cargar dato de contador</a></span></li><li><span><a href="#Carga-datos-climatológicos" data-toc-modified-id="Carga-datos-climatológicos-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Carga datos climatológicos</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Daily-merged-df" data-toc-modified-id="Daily-merged-df-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Daily merged df</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Curvas horarias

# %% [markdown]
# ## Cargar dato de contador

# %%
import pandas as pd
import os
import numpy as np

# %%
FIXED_COST = 0.044027
KWH_PRICE = 0.139 + FIXED_COST
KWH_PRICE
# Out:
# 0.183027

# %%
LOW_COST = 0.082 + FIXED_COST
HIGH_COST = 0.161 + FIXED_COST
LOW_COST, HIGH_COST
# Out:
# (0.126027, 0.20502700000000001)

# %%
os.listdir()
# Out:
# ['energy_analytics.html',
#  'energy_analytics.ipynb',
#  'infoenergy (1).csv',
#  'aemet_metadatos.json',
#  'infoenergy_6.csv',
#  'daily_merged_df.h5',
#  '02_energy_analytics_plain.ipynb',
#  'infoenergy (4).csv',
#  'merged_df.csv',
#  '.ipynb_checkpoints',
#  'merged_df.h5',
#  'infoenergy (2).csv',
#  'diario_aemet_sevilla.json',
#  'curvas_horarias.ipynb',
#  'daily_merged_df.csv',
#  'infoenergy.csv',
#  'infoenergy (3).csv',
#  'energy_analytics (3).html',
#  'temp.csv']

# %%
energy_csv_filenames = [val for val in os.listdir() if val.startswith('infoenergy')]
energy_csv_filenames
# Out:
# ['infoenergy (1).csv',
#  'infoenergy_6.csv',
#  'infoenergy (4).csv',
#  'infoenergy (2).csv',
#  'infoenergy.csv',
#  'infoenergy (3).csv']

# %%
# !head -n 5 infoenergy.csv
# Out:
# date;value
# 2019/02/05 01:00:00;1968
# 2019/02/05 02:00:00;1959
# 2019/02/05 03:00:00;1960
# 2019/02/05 04:00:00;1978

# %%
from tqdm import tqdm


# LOAD AND CONCAT
df_list = []

for filename in tqdm(energy_csv_filenames):
    temp_df = pd.read_csv(filename, sep=';')
    df_list.append(temp_df)    
    
df = pd.concat(df_list)

# TYPE THE DATA
df.date = pd.to_datetime(df.date, format="%Y/%m/%d %H:%M:%S")
df.value = df.value.astype('float')

# CHANGE COLUMNS
df.rename(columns={'value': 'kwh'}, inplace=True)
df.kwh = df.kwh.div(1000)

# SORT BY DATE
df.sort_values('date', ascending=True, inplace=True)
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 211.48it/s]

# %%
pd.to_datetime('2019-09').year
# Out:
# 2019

# %%
pd.date_range(start='2019-03-21', periods=4, freq='90D')
# Out:
# DatetimeIndex(['2019-03-21', '2019-06-19', '2019-09-17', '2019-12-16'], dtype='datetime64[ns]', freq='90D')

# %%
def get_year_season(date):
    
    year = date.year
    
    spring_begin_date = pd.to_datetime(str(year) + '-03-21')    
    
    break_date_series = pd.Series([spring_begin_date + pd.DateOffset(months=(3 * d)) 
                                   for d in np.arange(0, 4)], 
                                  index=['spring', 'summer', 'autumn', 'winter'])
   
    aux_series = break_date_series.le(date)
    if aux_series.sum() == 0:
        season = 'winter'
    else:
        season = aux_series[aux_series == True].index[-1]      
        
    return season
    
get_year_season(pd.to_datetime('2019-04-21'))
# Out:
# 'spring'

# %%
def get_season_from_date_series(date_series):
    
    month_series = date_series.dt.month
    day_number_modifier_series = date_series.dt.day.ge(21).mul(0.5)
    date_repr_series = month_series.add(day_number_modifier_series)
    
    season_series = pd.cut(date_repr_series, 
                           bins=[3.1, 6.1, 9.1, 12.1], 
                           labels=['spring', 'summer', 'autumn']).astype('object')
    season_series.fillna('winter', inplace=True)
    
    return season_series

# %%
def get_last_sunday_of_month(year_month):
    """ year_month must be %Y-%m """
    time_stamp = pd.to_datetime(year_month)
    date_range = pd.date_range(start=time_stamp, 
                               periods=31).to_series()
    date_range = date_range[date_range.dt.month.eq(time_stamp.month)]
    dow_series = date_range.dt.weekday_name.copy()
    
    dow_series.drop_duplicates(keep='last', inplace=True)
    val_date_index = dow_series.loc[dow_series.eq('Sunday')].index[0]
    
    return date_range.loc[val_date_index]
    
get_last_sunday_of_month('2019-05')
# Out:
# Timestamp('2019-05-26 00:00:00')

# %%
def get_feat_eng(df):
    feat_eng_df = df.copy()
    feat_eng_df.insert( 1, 'daily_date', feat_eng_df.date.dt.to_period('D'))
    feat_eng_df['dow'] = feat_eng_df.date.dt.weekday_name
    feat_eng_df['is_weekend'] = feat_eng_df.dow.isin(['Saturday', 'Sunday'])
    feat_eng_df['hour'] = feat_eng_df.date.dt.hour
    feat_eng_df['is_working_time'] = feat_eng_df.hour.between(9, 19, inclusive=True)
    feat_eng_df['is_night_time'] = feat_eng_df.hour.between(0, 8, inclusive=True)
    feat_eng_df['season'] = get_season_from_date_series(feat_eng_df.date)
    feat_eng_df['cost'] = feat_eng_df.kwh.mul(KWH_PRICE)
    feat_eng_df['discriminative_cost'] = (feat_eng_df.kwh.mul(feat_eng_df.hour.between(12, 22))
                                                         .mul(HIGH_COST)
                                                         .add(
                                          feat_eng_df.kwh.mul(~feat_eng_df.hour.between(12, 22)).mul(LOW_COST)))
    
    return feat_eng_df

# %%
df = get_feat_eng(df)
df.head()
# Out:
#                  date  daily_date    kwh      dow  is_weekend  hour  \
# 0 2019-02-05 01:00:00  2019-02-05  1.968  Tuesday       False     1
# 1 2019-02-05 02:00:00  2019-02-05  1.959  Tuesday       False     2
# 2 2019-02-05 03:00:00  2019-02-05  1.960  Tuesday       False     3
# 3 2019-02-05 04:00:00  2019-02-05  1.978  Tuesday       False     4
# 4 2019-02-05 05:00:00  2019-02-05  1.892  Tuesday       False     5
#
#    is_working_time  is_night_time  season      cost  discriminative_cost
# 0            False           True  winter  0.360197             0.248021
# 1            False           True  winter  0.358550             0.246887
# 2            False           True  winter  0.358733             0.247013
# 3            False           True  winter  0.362027             0.249281
# 4            False           True  winter  0.346287             0.238443

# %%
df.shape
# Out:
# (3024, 11)

# %%
df.season.value_counts()
# Out:
# spring    1969
# winter    1055
# Name: season, dtype: int64

# %%
df.tail()
# Out:
#                    date  daily_date    kwh        dow  is_weekend  hour  \
# 118 2019-06-05 22:00:00  2019-06-05  0.229  Wednesday       False    22
# 119 2019-06-05 23:00:00  2019-06-05  0.265  Wednesday       False    23
# 119 2019-06-05 23:00:00  2019-06-05  0.265  Wednesday       False    23
# 120 2019-06-06 00:00:00  2019-06-06  0.281   Thursday       False     0
# 120 2019-06-06 00:00:00  2019-06-06  0.281   Thursday       False     0
#
#      is_working_time  is_night_time  season      cost  discriminative_cost
# 118            False          False  spring  0.041913             0.046951
# 119            False          False  spring  0.048502             0.033397
# 119            False          False  spring  0.048502             0.033397
# 120            False           True  spring  0.051431             0.035414
# 120            False           True  spring  0.051431             0.035414

# %%
df.tail()
# Out:
#                    date  daily_date    kwh        dow  is_weekend  hour  \
# 118 2019-06-05 22:00:00  2019-06-05  0.229  Wednesday       False    22
# 119 2019-06-05 23:00:00  2019-06-05  0.265  Wednesday       False    23
# 119 2019-06-05 23:00:00  2019-06-05  0.265  Wednesday       False    23
# 120 2019-06-06 00:00:00  2019-06-06  0.281   Thursday       False     0
# 120 2019-06-06 00:00:00  2019-06-06  0.281   Thursday       False     0
#
#      is_working_time  is_night_time  season      cost  discriminative_cost
# 118            False          False  spring  0.041913             0.046951
# 119            False          False  spring  0.048502             0.033397
# 119            False          False  spring  0.048502             0.033397
# 120            False           True  spring  0.051431             0.035414
# 120            False           True  spring  0.051431             0.035414

# %%
df.shape
# Out:
# (3024, 11)

# %%
df.dtypes
# Out:
# date                   datetime64[ns]
# daily_date                  period[D]
# kwh                           float64
# dow                            object
# is_weekend                       bool
# hour                            int64
# is_working_time                  bool
# is_night_time                    bool
# season                         object
# cost                          float64
# discriminative_cost           float64
# dtype: object

# %%
df.head()
# Out:
#                  date  daily_date    kwh      dow  is_weekend  hour  \
# 0 2019-02-05 01:00:00  2019-02-05  1.968  Tuesday       False     1
# 1 2019-02-05 02:00:00  2019-02-05  1.959  Tuesday       False     2
# 2 2019-02-05 03:00:00  2019-02-05  1.960  Tuesday       False     3
# 3 2019-02-05 04:00:00  2019-02-05  1.978  Tuesday       False     4
# 4 2019-02-05 05:00:00  2019-02-05  1.892  Tuesday       False     5
#
#    is_working_time  is_night_time  season      cost  discriminative_cost
# 0            False           True  winter  0.360197             0.248021
# 1            False           True  winter  0.358550             0.246887
# 2            False           True  winter  0.358733             0.247013
# 3            False           True  winter  0.362027             0.249281
# 4            False           True  winter  0.346287             0.238443

# %% [markdown]
# ## Carga datos climatológicos

# %%
import json
from pprint import pprint


with open('diario_aemet_sevilla.json', mode='r') as file:
    climate_data = json.load(file)

# %%
pprint(climate_data[0])
# Out:
# {'altitud': '34',
#  'dir': '99',
#  'fecha': '2019-02-01',
#  'horaPresMax': 'Varias',
#  'horaPresMin': '05',
#  'horaracha': 'Varias',
#  'horatmax': '12:42',
#  'horatmin': '22:37',
#  'indicativo': '5783',
#  'nombre': 'SEVILLA AEROPUERTO',
#  'prec': '0,2',
#  'presMax': '1006,3',
#  'presMin': '996,3',
#  'provincia': 'SEVILLA',
#  'racha': '19,7',
#  'sol': '7,1',
#  'tmax': '16,4',
#  'tmed': '12,2',
#  'tmin': '7,9',
#  'velmedia': '6,7'}

# %%
pd.options.display.max_columns = 500

# %%
# aux_df = pd.read_json('diario_aemet_sevilla.json', )
# aux_df

# %%
def get_circular_col(circ_series):
    
    max_val = circ_series.max()
    min_val = circ_series.min()
    range_val = max_val - min_val
    
    axis_1_arr = np.cos((circ_series.values - min_val) / range_val * 2 * np.pi)
    axis_2_arr = np.sin((circ_series.values - min_val) / range_val * 2 * np.pi)
    
    axis_1_series = pd.Series(axis_1_arr, index=circ_series.index)
    axis_2_series = pd.Series(axis_2_arr, index=circ_series.index)
    
    return axis_1_series, axis_2_series

# %%
climate_df = pd.DataFrame(climate_data)
climate_df.rename(columns={'fecha': 'daily_date'}, inplace=True)
climate_df.daily_date = pd.to_datetime(climate_df.daily_date, 
                                 format="%Y-%m-%d", 
                                 errors='coerce'
                                )
climate_df.replace(',', '.', inplace=True, regex=True)
float_cols = ['dir', 'prec', 'presMax', 'presMin', 'racha', 'sol',
              'tmax', 'tmed', 'tmin', 'velmedia']
climate_df.prec = climate_df.prec.replace('Ip', np.nan)
climate_df[float_cols] = climate_df[float_cols].astype(np.float64)
# for col in float_cols:
#     try:
#         climate_df[col] = climate_df[col].astype(np.float64)
#     except:
#         print(col)
climate_df = climate_df.infer_objects()
climate_df.daily_date = climate_df.daily_date.dt.to_period('D')
climate_df = climate_df.loc(axis=1)[climate_df.nunique() > 1]

climate_df['dir_axis_1'], climate_df['dir_axis_2'] = get_circular_col(climate_df.dir)

climate_df.drop('dir', axis=1, inplace=True)
climate_df.head()
# Out:
#    daily_date horaPresMax horaPresMin horaracha horatmax horatmin  prec  \
# 0  2019-02-01      Varias          05    Varias    12:42    22:37   0.2
# 1  2019-02-02      Varias          00    Varias    14:26    23:20   0.0
# 2  2019-02-03      Varias          00       NaN    15:48    07:01   0.0
# 3  2019-02-04      Varias          16    Varias    16:14    05:11   0.0
# 4  2019-02-05      Varias          17     07:12    16:01    07:05   0.0
#
#    presMax  presMin  racha   sol  tmax  tmed  tmin  velmedia  dir_axis_1  \
# 0   1006.3    996.3   19.7   7.1  16.4  12.2   7.9       6.7    1.000000
# 1   1020.1   1006.1   12.8   9.9  15.3  10.0   4.8       6.4    1.000000
# 2   1026.6   1020.1    6.7  10.1  14.4   7.9   1.4       1.4    0.981559
# 3   1026.9   1023.6    8.9  10.1  16.3   9.2   2.1       3.1    1.000000
# 4   1026.1   1022.8    8.3  10.2  20.3  11.9   3.5       1.9    0.991790
#
#      dir_axis_2
# 0 -2.449294e-16
# 1 -2.449294e-16
# 2  1.911586e-01
# 3 -2.449294e-16
# 4  1.278772e-01

# %%
climate_df.prec.unique()
# Out:
# array([ 0.2,  0. ,  0.1,  nan,  0.5,  4.6, 11.6,  8. ,  2.5,  3.2,  5.7,
#        10.2,  1.3,  6.2,  1.9,  8.3,  1.2, 15.4])

# %%
climate_df.tail()
# Out:
#      daily_date horaPresMax horaPresMin horaracha horatmax horatmin  prec  \
# 144  2019-06-25      Varias          17    Varias    16:39    03:55   0.0
# 145  2019-06-26      Varias          17    Varias    16:38    02:52   0.0
# 146  2019-06-27      Varias          18     13:50    16:30    04:45   0.0
# 147  2019-06-28          00          17     17:47    16:09    04:30   0.0
# 148  2019-06-29      Varias          17    Varias    15:20    05:03   0.0
#
#      presMax  presMin  racha   sol  tmax  tmed  tmin  velmedia  dir_axis_1  \
# 144   1012.7   1009.2    8.9  14.2  32.8  25.4  17.9       3.9    0.222521
# 145   1014.2   1010.4    9.2  13.1  32.1  25.8  19.5       3.9    1.000000
# 146   1013.7   1010.4   10.3  13.6  31.8  25.3  18.8       4.2   -0.032052
# 147   1012.7   1007.5    9.2  13.6  35.9  27.6  19.3       3.3    0.284528
# 148   1012.1   1008.3   10.8  13.8  36.9  29.2  21.6       4.2    0.222521
#
#        dir_axis_2
# 144  9.749279e-01
# 145 -2.449294e-16
# 146  9.994862e-01
# 147  9.586679e-01
# 148  9.749279e-01

# %%
climate_df.dtypes
# Out:
# daily_date     period[D]
# horaPresMax       object
# horaPresMin       object
# horaracha         object
# horatmax          object
# horatmin          object
# prec             float64
# presMax          float64
# presMin          float64
# racha            float64
# sol              float64
# tmax             float64
# tmed             float64
# tmin             float64
# velmedia         float64
# dir_axis_1       float64
# dir_axis_2       float64
# dtype: object

# %%
climate_df.head()
# Out:
#    daily_date horaPresMax horaPresMin horaracha horatmax horatmin  prec  \
# 0  2019-02-01      Varias          05    Varias    12:42    22:37   0.2
# 1  2019-02-02      Varias          00    Varias    14:26    23:20   0.0
# 2  2019-02-03      Varias          00       NaN    15:48    07:01   0.0
# 3  2019-02-04      Varias          16    Varias    16:14    05:11   0.0
# 4  2019-02-05      Varias          17     07:12    16:01    07:05   0.0
#
#    presMax  presMin  racha   sol  tmax  tmed  tmin  velmedia  dir_axis_1  \
# 0   1006.3    996.3   19.7   7.1  16.4  12.2   7.9       6.7    1.000000
# 1   1020.1   1006.1   12.8   9.9  15.3  10.0   4.8       6.4    1.000000
# 2   1026.6   1020.1    6.7  10.1  14.4   7.9   1.4       1.4    0.981559
# 3   1026.9   1023.6    8.9  10.1  16.3   9.2   2.1       3.1    1.000000
# 4   1026.1   1022.8    8.3  10.2  20.3  11.9   3.5       1.9    0.991790
#
#      dir_axis_2
# 0 -2.449294e-16
# 1 -2.449294e-16
# 2  1.911586e-01
# 3 -2.449294e-16
# 4  1.278772e-01

# %%
climate_df.isnull().sum()
# Out:
# daily_date     0
# horaPresMax    0
# horaPresMin    0
# horaracha      2
# horatmax       0
# horatmin       0
# prec           4
# presMax        0
# presMin        0
# racha          1
# sol            1
# tmax           0
# tmed           0
# tmin           0
# velmedia       0
# dir_axis_1     1
# dir_axis_2     1
# dtype: int64

# %%
merged_df = pd.merge(df, climate_df, how='left', on='daily_date', validate='many_to_one')
merged_df.set_index('date', inplace=True)

# %%
merged_df.head()
# Out:
#                      daily_date    kwh      dow  is_weekend  hour  \
# date
# 2019-02-05 01:00:00  2019-02-05  1.968  Tuesday       False     1
# 2019-02-05 02:00:00  2019-02-05  1.959  Tuesday       False     2
# 2019-02-05 03:00:00  2019-02-05  1.960  Tuesday       False     3
# 2019-02-05 04:00:00  2019-02-05  1.978  Tuesday       False     4
# 2019-02-05 05:00:00  2019-02-05  1.892  Tuesday       False     5
#
#                      is_working_time  is_night_time  season      cost  \
# date
# 2019-02-05 01:00:00            False           True  winter  0.360197
# 2019-02-05 02:00:00            False           True  winter  0.358550
# 2019-02-05 03:00:00            False           True  winter  0.358733
# 2019-02-05 04:00:00            False           True  winter  0.362027
# 2019-02-05 05:00:00            False           True  winter  0.346287
#
#                      discriminative_cost horaPresMax horaPresMin horaracha  \
# date
# 2019-02-05 01:00:00             0.248021      Varias          17     07:12
# 2019-02-05 02:00:00             0.246887      Varias          17     07:12
# 2019-02-05 03:00:00             0.247013      Varias          17     07:12
# 2019-02-05 04:00:00             0.249281      Varias          17     07:12
# 2019-02-05 05:00:00             0.238443      Varias          17     07:12
#
#                     horatmax horatmin  prec  presMax  presMin  racha   sol  \
# date
# 2019-02-05 01:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
# 2019-02-05 02:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
# 2019-02-05 03:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
# 2019-02-05 04:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
# 2019-02-05 05:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
#
#                      tmax  tmed  tmin  velmedia  dir_axis_1  dir_axis_2
# date
# 2019-02-05 01:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877
# 2019-02-05 02:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877
# 2019-02-05 03:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877
# 2019-02-05 04:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877
# 2019-02-05 05:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877

# %%
q = merged_df.resample('6H' ) #.interpolate()
# q.interpolate()

# %%
merged_df.resample('6H', ).mean()
# Out:
#                           kwh  is_weekend  hour  is_working_time  \
# date
# 2019-02-05 00:00:00  1.951400         0.0   3.0         0.000000
# 2019-02-05 06:00:00  1.804667         0.0   8.5         0.500000
# 2019-02-05 12:00:00  1.264833         0.0  14.5         1.000000
# 2019-02-05 18:00:00  1.372000         0.0  20.5         0.333333
# 2019-02-06 00:00:00  1.659000         0.0   2.5         0.000000
# 2019-02-06 06:00:00  1.639333         0.0   8.5         0.500000
# 2019-02-06 12:00:00  0.548000         0.0  14.5         1.000000
# 2019-02-06 18:00:00  0.332667         0.0  20.5         0.333333
# 2019-02-07 00:00:00  0.662833         0.0   2.5         0.000000
# 2019-02-07 06:00:00  0.502833         0.0   8.5         0.500000
# 2019-02-07 12:00:00  0.518000         0.0  14.5         1.000000
# 2019-02-07 18:00:00  0.248333         0.0  20.5         0.333333
# 2019-02-08 00:00:00  0.119333         0.0   2.5         0.000000
# 2019-02-08 06:00:00  0.565833         0.0   8.5         0.500000
# 2019-02-08 12:00:00  0.844833         0.0  14.5         1.000000
# 2019-02-08 18:00:00  0.427500         0.0  20.5         0.333333
# 2019-02-09 00:00:00  0.756667         1.0   2.5         0.000000
# 2019-02-09 06:00:00  0.118500         1.0   8.5         0.500000
# 2019-02-09 12:00:00  0.590167         1.0  14.5         1.000000
# 2019-02-09 18:00:00  0.397000         1.0  20.5         0.333333
# 2019-02-10 00:00:00  0.180167         1.0   2.5         0.000000
# 2019-02-10 06:00:00  0.128333         1.0   8.5         0.500000
# 3     0.358733
# 4     0.362027
# 5     0.346287
# 6     0.331279
# 7     0.354523
# 8     0.348666
# 9     0.351229
# 10    0.226038
# 11    0.372460
# 12    0.287169
# 13    0.318101
# 14    0.379232
# 15    0.345921
# 16    0.319016
# 17    0.224574
# 18    0.279116
# 19    0.260630
# 20    0.272161
# 21    0.305655
# 22    0.347751
# 23    0.345006

# %%
basal_kwh_consum = merged_df.resample('D').kwh.min().quantile(0.5)
basal_kwh_consum
# Out:
# 0.1025

# %%
merged_df.kwh.min()
# Out:
# 0.079

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='hour', y='kwh', data=merged_df);
plt.ylim(0.0, 1.00)
# Out:
# (0.0, 1.0)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='dow', y='kwh', data=merged_df);

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='is_weekend', y='kwh', data=merged_df) #, whis="range", palette="vlag");

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='season', y='kwh', data=df) #, whis="range", palette="vlag");

# %%
merged_df.resample('M').kwh.mean().plot();

# %%
merged_df.resample('M')[['cost', 'discriminative_cost']].mean()
# Out:
#                 cost  discriminative_cost
# date
# 2019-02-28  0.078951             0.068914
# 2019-03-31  0.039240             0.036535
# 2019-04-30  0.041013             0.037743
# 2019-05-31  0.043361             0.040568
# 2019-06-30  0.047569             0.045390

# %%
merged_df.resample('M')[['cost', 'discriminative_cost']].mean().plot()
plt.legend();

# %%
merged_df.loc[merged_df.is_working_time.eq(True)].resample('M')[['cost', 'discriminative_cost']].mean().plot()
plt.legend();

# %%
merged_df.loc[merged_df.is_working_time.eq(False)].resample('M')[['cost', 'discriminative_cost']].mean().plot()
plt.legend();

# %% [markdown]
# ## Daily merged df

# %%
daily_merged_df = merged_df.resample('D').mean()
daily_merged_df.head()
# Out:
#                  kwh  is_weekend  hour  is_working_time  is_night_time  \
# date
# 2019-02-05  1.582870         0.0  12.0         0.478261       0.347826
# 2019-02-06  1.044750         0.0  11.5         0.458333       0.375000
# 2019-02-07  0.483000         0.0  11.5         0.458333       0.375000
# 2019-02-08  0.489375         0.0  11.5         0.458333       0.375000
# 2019-02-09  0.465583         1.0  11.5         0.458333       0.375000
#
#                 cost  discriminative_cost  prec  presMax  presMin  racha  \
# date
# 2019-02-05  0.289708             0.248427   0.0   1026.1   1022.8    8.3
# 2019-02-06  0.191217             0.145893   0.0   1023.5   1019.8    6.7
# 2019-02-07  0.088402             0.075275   0.0   1022.0   1018.5    5.0
# 2019-02-08  0.089569             0.086020   0.1   1021.3   1018.3    4.7
# 2019-02-09  0.085214             0.074453   NaN   1022.0   1018.8    5.0
#
#              sol  tmax  tmed  tmin  velmedia  dir_axis_1    dir_axis_2
# date
# 2019-02-05  10.2  20.3  11.9   3.5       1.9    0.991790  1.278772e-01
# 2019-02-06   9.8  21.2  13.0   4.9       1.9    0.967295  2.536546e-01
# 2019-02-07   9.9  21.2  13.0   4.9       1.9    1.000000 -2.449294e-16
# 2019-02-08  10.1  19.3  12.2   5.1       2.2    1.000000 -2.449294e-16
# 2019-02-09   9.9  18.1  10.5   2.9       1.7    0.284528  9.586679e-01

# %%
sns.jointplot(x='tmed', y='kwh', data=daily_merged_df)
# Out:
# /home/infinitemonkeys/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/infinitemonkeys/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
daily_merged_df.corr().kwh.sort_values(ascending=False)
# Out:
# kwh                    1.000000
# cost                   1.000000
# discriminative_cost    0.990011
# presMin                0.249912
# presMax                0.248393
# dir_axis_1             0.164895
# hour                   0.020456
# is_working_time        0.019976
# is_night_time         -0.019976
# prec                  -0.024607
# sol                   -0.042313
# velmedia              -0.107124
# dir_axis_2            -0.164404
# tmax                  -0.174860
# racha                 -0.182203
# is_weekend            -0.199720
# tmed                  -0.232268
# tmin                  -0.274036
# Name: kwh, dtype: float64

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(daily_merged_df.corr(), cmap='Blues');

# %%
plt.figure(figsize=(15, 6))
daily_merged_df.kwh.plot();
daily_merged_df.kwh.rolling(5, center=True).mean().plot();

# %%
daily_merged_df.head()
# Out:
#                  kwh  is_weekend  hour  is_working_time  is_night_time  \
# date
# 2019-02-05  1.582870         0.0  12.0         0.478261       0.347826
# 2019-02-06  1.044750         0.0  11.5         0.458333       0.375000
# 2019-02-07  0.483000         0.0  11.5         0.458333       0.375000
# 2019-02-08  0.489375         0.0  11.5         0.458333       0.375000
# 2019-02-09  0.465583         1.0  11.5         0.458333       0.375000
#
#                 cost  discriminative_cost  prec  presMax  presMin  racha  \
# date
# 2019-02-05  0.289708             0.248427   0.0   1026.1   1022.8    8.3
# 2019-02-06  0.191217             0.145893   0.0   1023.5   1019.8    6.7
# 2019-02-07  0.088402             0.075275   0.0   1022.0   1018.5    5.0
# 2019-02-08  0.089569             0.086020   0.1   1021.3   1018.3    4.7
# 2019-02-09  0.085214             0.074453   NaN   1022.0   1018.8    5.0
#
#              sol  tmax  tmed  tmin  velmedia  dir_axis_1    dir_axis_2
# date
# 2019-02-05  10.2  20.3  11.9   3.5       1.9    0.991790  1.278772e-01
# 2019-02-06   9.8  21.2  13.0   4.9       1.9    0.967295  2.536546e-01
# 2019-02-07   9.9  21.2  13.0   4.9       1.9    1.000000 -2.449294e-16
# 2019-02-08  10.1  19.3  12.2   5.1       2.2    1.000000 -2.449294e-16
# 2019-02-09   9.9  18.1  10.5   2.9       1.7    0.284528  9.586679e-01

# %%
merged_df.head()
# Out:
#                      daily_date    kwh      dow  is_weekend  hour  \
# date
# 2019-02-05 01:00:00  2019-02-05  1.968  Tuesday       False     1
# 2019-02-05 02:00:00  2019-02-05  1.959  Tuesday       False     2
# 2019-02-05 03:00:00  2019-02-05  1.960  Tuesday       False     3
# 2019-02-05 04:00:00  2019-02-05  1.978  Tuesday       False     4
# 2019-02-05 05:00:00  2019-02-05  1.892  Tuesday       False     5
#
#                      is_working_time  is_night_time  season      cost  \
# date
# 2019-02-05 01:00:00            False           True  winter  0.360197
# 2019-02-05 02:00:00            False           True  winter  0.358550
# 2019-02-05 03:00:00            False           True  winter  0.358733
# 2019-02-05 04:00:00            False           True  winter  0.362027
# 2019-02-05 05:00:00            False           True  winter  0.346287
#
#                      discriminative_cost horaPresMax horaPresMin horaracha  \
# date
# 2019-02-05 01:00:00             0.248021      Varias          17     07:12
# 2019-02-05 02:00:00             0.246887      Varias          17     07:12
# 2019-02-05 03:00:00             0.247013      Varias          17     07:12
# 2019-02-05 04:00:00             0.249281      Varias          17     07:12
# 2019-02-05 05:00:00             0.238443      Varias          17     07:12
#
#                     horatmax horatmin  prec  presMax  presMin  racha   sol  \
# date
# 2019-02-05 01:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
# 2019-02-05 02:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
# 2019-02-05 03:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
# 2019-02-05 04:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
# 2019-02-05 05:00:00    16:01    07:05   0.0   1026.1   1022.8    8.3  10.2
#
#                      tmax  tmed  tmin  velmedia  dir_axis_1  dir_axis_2
# date
# 2019-02-05 01:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877
# 2019-02-05 02:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877
# 2019-02-05 03:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877
# 2019-02-05 04:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877
# 2019-02-05 05:00:00  20.3  11.9   3.5       1.9     0.99179    0.127877

# %%
merged_df.to_csv('merged_df.csv')
daily_merged_df.to_csv('daily_merged_df.csv')

# %%
daily_merged_df.to_hdf('daily_merged_df.h5',
                  'dataset',
                  mode='w',
                  complevel=9,
                  complib='blosc:snappy')

# %%
merged_to_save_df = merged_df.copy()
merged_to_save_df.daily_date = merged_to_save_df.daily_date.astype('str')

merged_to_save_df.to_hdf('merged_df.h5',
                  'dataset',
                  mode='w',
                  complevel=9,
                  complib='blosc:snappy')
# Out:
# /home/infinitemonkeys/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->['daily_date', 'dow', 'season', 'horaPresMax', 'horaPresMin', 'horaracha', 'horatmax', 'horatmin']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
loaded_csv = pd.read_csv(filepath_or_buffer='daily_merged_df.csv')
loaded_csv = pd.read_csv(**{'filepath_or_buffer': 'daily_merged_df.csv'})

# %%
loaded_hdf = pd.read_hdf('daily_merged_df.h5')

# %%
loaded_csv = pd.read_csv('merged_df.csv')

# %%
loaded_hdf = pd.read_hdf('merged_df.h5')

# %%
daily_merged_df.dtypes
# Out:
# kwh                    float64
# is_weekend             float64
# hour                   float64
# is_working_time        float64
# is_night_time          float64
# cost                   float64
# discriminative_cost    float64
# prec                   float64
# presMax                float64
# presMin                float64
# racha                  float64
# sol                    float64
# tmax                   float64
# tmed                   float64
# tmin                   float64
# velmedia               float64
# dir_axis_1             float64
# dir_axis_2             float64
# dtype: object

# %%
merged_df.dtypes
# Out:
# daily_date             period[D]
# kwh                      float64
# dow                       object
# is_weekend                  bool
# hour                       int64
# is_working_time             bool
# is_night_time               bool
# season                    object
# cost                     float64
# discriminative_cost      float64
# horaPresMax               object
# horaPresMin               object
# horaracha                 object
# horatmax                  object
# horatmin                  object
# prec                     float64
# presMax                  float64
# presMin                  float64
# racha                    float64
# sol                      float64
# tmax                     float64
# tmed                     float64
# tmin                     float64
# velmedia                 float64
# dir_axis_1               float64
# dir_axis_2               float64
# dtype: object

# %%
# !head -n 1 merged_df.csv
# Out:
# date,daily_date,kwh,dow,is_weekend,hour,is_working_time,is_night_time,season,cost,discriminative_cost,horaPresMax,horaPresMin,horaracha,horatmax,horatmin,prec,presMax,presMin,racha,sol,tmax,tmed,tmin,velmedia,dir_axis_1,dir_axis_2
