# %% [markdown]
# # Creando gráficas con Matplotlib
#
# La función `pyplot` es la encargada de ejecutar las gráficas. Matplotlib crea figuras que en las que `pyplot` pinta lo que se estipule.
#
# Con el comando mágico de IPython `%matplotlib`  establecemos el formato de salida de la figura
# - `%matplotlib inline` - dentro del notebook.
# - `%matplotlib qt` - fuera del notebook en ventana emergente usando la aplicación QT.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 10, 100) #genera un vector de puntos en el eje X

fig = plt.figure() #genera una figura nueva
plt.plot(x, np.sin(x), '-') #pinta los valores (x,sin(x))
plt.plot(x, np.cos(x), '--'); #pinta los valores (x,cos(x))

# %% [markdown]
# Modificamos el tamaño de la figura con la opción `figsize` en `figure`.

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure(figsize=(3,2))
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %% [markdown]
# Se puede salvar la figura actual con el método `savefig`

# %%
fig.savefig('guardaimagen.png')

# %% [markdown]
# <img src='guardaimagen.png',width=100>

# %% [markdown]
# # Representación orientada a objetos
#
# Se puede usar Matplotlib al estilo Matlab ó como programación orientada a objetos. Esta última permite más posibilidades.
#
# Para generar múltiples figuras creamos una instancia `subplots`. Esta tiene las características:
#
#
#     Keyword arguments:
#
#       *nrows* : int
#         Number of rows of the subplot grid.  Defaults to 1.
#
#       *ncols* : int
#         Number of columns of the subplot grid.  Defaults to 1.
#
#       *sharex* : string or bool
#         If *True*, the X axis will be shared amongst all subplots.  If
#         *True* and you have multiple rows, the x tick labels on all but
#         the last row of plots will have visible set to *False*
#         If a string must be one of "row", "col", "all", or "none".
#         "all" has the same effect as *True*, "none" has the same effect
#         as *False*.
#         If "row", each subplot row will share a X axis.
#         If "col", each subplot column will share a X axis and the x tick
#         labels on all but the last row will have visible set to *False*.
#
#       *sharey* : string or bool
#         If *True*, the Y axis will be shared amongst all subplots. If
#         *True* and you have multiple columns, the y tick labels on all but
#         the first column of plots will have visible set to *False*
#         If a string must be one of "row", "col", "all", or "none".
#         "all" has the same effect as *True*, "none" has the same effect
#         as *False*.
#         If "row", each subplot row will share a Y axis and the y tick
#         labels on all but the first column will have visible set to *False*.
#         If "col", each subplot column will share a Y axis.
#
#       *squeeze* : bool
#         If *True*, extra dimensions are squeezed out from the
#         returned axis object:
#
#         - if only one subplot is constructed (nrows=ncols=1), the
#           resulting single Axis object is returned as a scalar.
#
#         - for Nx1 or 1xN subplots, the returned object is a 1-d numpy
#           object array of Axis objects are returned as numpy 1-d
#           arrays.
#
#         - for NxM subplots with N>1 and M>1 are returned as a 2d
#           array.
#
#         If *False*, no squeezing at all is done: the returned axis
#         object is always a 2-d array containing Axis instances, even if it
#         ends up being 1x1.
#
#       *subplot_kw* : dict
#         Dict with keywords passed to the
#         :meth:`~matplotlib.figure.Figure.add_subplot` call used to
#         create each subplots.
#
#       *gridspec_kw* : dict
#         Dict with keywords passed to the
#         :class:`~matplotlib.gridspec.GridSpec` constructor used to create
#         the grid the subplots are placed on.
#
#       *fig_kw* : dict
#         Dict with keywords passed to the :func:`figure` call.  Note that all
#         keywords not recognized above will be automatically included here.

# %%
# ?plt.subplots

# %%
#creamos una figura y definimos las posiciones en ejes
fig, ax = plt.subplots(2)

#pintamos en cada eje 
ax[0].plot(x, np.sin(x))
ax[1].plot(x, 2*np.cos(x));

# %% [markdown]
# <!--NAVIGATION-->
# [Gráficos de curvas](01 - gráficos de curvas.ipynb) >
