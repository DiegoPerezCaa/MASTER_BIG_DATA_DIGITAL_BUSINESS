# %% [markdown]
# # Gráficos de curvas
#
# Representación de gráficas 2D de funciones de formato $y=f(x)$.

# %%
# !pip install seaborn

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import numpy as np

# %% [markdown]
# ### Estilos de dibujado
#
# https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
# ?plt.style.use

# %% [markdown]
# Lista de estilos de gráficas disponibles

# %%
plt.style.available
# Out:
# ['seaborn-darkgrid',
#  'seaborn-paper',
#  'ggplot',
#  'classic',
#  'dark_background',
#  'grayscale',
#  'seaborn-whitegrid',
#  'seaborn-notebook',
#  'seaborn-pastel',
#  'seaborn-ticks',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-white',
#  'seaborn-dark',
#  'fivethirtyeight',
#  'seaborn-deep',
#  'bmh',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-muted',
#  'seaborn-colorblind']

# %%
len(plt.style.available) #hay 21 estilos
# Out:
# 21

# %% [markdown]
# Aquí tenemos un ejemplo con todos los estilos

# %%
[(j,k) for (j,k) in enumerate(plt.style.available)]
# Out:
# [(0, 'seaborn-darkgrid'),
#  (1, 'seaborn-paper'),
#  (2, 'ggplot'),
#  (3, 'classic'),
#  (4, 'dark_background'),
#  (5, 'grayscale'),
#  (6, 'seaborn-whitegrid'),
#  (7, 'seaborn-notebook'),
#  (8, 'seaborn-pastel'),
#  (9, 'seaborn-ticks'),
#  (10, 'seaborn-dark-palette'),
#  (11, 'seaborn-bright'),
#  (12, 'seaborn-white'),
#  (13, 'seaborn-dark'),
#  (14, 'fivethirtyeight'),
#  (15, 'seaborn-deep'),
#  (16, 'bmh'),
#  (17, 'seaborn-poster'),
#  (18, 'seaborn-talk'),
#  (19, 'seaborn-muted'),
#  (20, 'seaborn-colorblind')]

# %%
from matplotlib import gridspec
gs = gridspec.GridSpec(7, 3,hspace=1,wspace=0.5)

for j,k in enumerate(plt.style.available):  
    with plt.style.context((k)):
        temp=plt.subplot(gs[j]) 
        temp.plot(np.sin(np.linspace(0, 2 * np.pi)), '--b')

# %% [markdown]
# La función principal para el dibujado es `plot`

# %%
# ?plt.plot

# %%
fig = plt.figure()
ax = plt.axes() #es el objeto que pinta los ejes

# %% [markdown]
# Al final del comando de ejecución del dibujo ponemos `;` para evitar que escriba el nombre interno del objeto gráfico creado

# %%
fig = plt.figure()
ax = plt.axes() #es el objeto que pinta los ejes

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x),'b');

# %% [markdown]
# Otro modo alternativo de crear la misma gráfica directamente es usar el interfaz de dibujado directo inspirado en Matlab

# %%
plt.plot(x, np.sin(x),'--g');

# %%
xx=np.linspace(0,10,20)

# %%
plt.plot(xx, np.sin(xx),'-or')
plt.plot(xx, np.cos(xx),'-xy');

# %% [markdown]
# ### Establecer colores
#
# Si %matplotlib qt da problemas, ejecutar
#
#         sudo apt-get install libqt4-dev

# %%
plt.figure(figsize=(7,5))
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %% [markdown]
# ### Estilos de línea

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# se puede escribir lo anterior de manera abreviada como
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# Se puede combinar toda esta información en un sólo parámetro con color y formato de línea

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# ### Ajustar los límites de los ejes

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %%
plt.plot(x, np.sin(x))
plt.axis('tight'); #comando ajustado predefinido

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# ### Etiquetado de ejes y título

# %%
plt.plot(x, np.sin(x))
plt.title("La curva sinusoidal",loc='right')
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# ### Leyenda de las curvas

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# Otra opción es darla al final con opciones de posicionamiento, por defecto `'best'`
#
#     ===============   =============
#             Location String   Location Code
#             ===============   =============
#             'best'            0
#             'upper right'     1
#             'upper left'      2
#             'lower left'      3
#             'lower right'     4
#             'right'           5
#             'center left'     6
#             'center right'    7
#             'lower center'    8
#             'upper center'    9
#             'center'          10
#             ===============   =============

# %%
plt.plot(x, np.sin(x), '-g');
plt.plot(x, np.cos(x), ':b');
plt.axis('equal');
plt.legend(['sin(x)','cos(x)'],loc=4);

# %% [markdown]
# <!--NAVIGATION-->
# < [Básico](00 - matplotlib.ipynb) || [Scatterplots](02 - Scatterplots.ipynb) >
