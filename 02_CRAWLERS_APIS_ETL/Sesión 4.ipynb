# %% [markdown]
# # Extracción de datos web

# %% [markdown]
# ## Índice
# 1. [Navegador web en Python (socket)](#socket)
# 2. [Recepción de páginas web con urllib](#urllib)
# 3. [Parsing de HTML mediante BeatifulSoup](#bea)
# 4. [Ejemplos de web scraping](#ejemplos)

# %% [markdown]
# <a id="socket"></a>
# ## Navegador web en Python (socket)

# %% [markdown]
# Vamos a crear nuestro primer navegador web utilizando el protocolo HTTP, realizando una conexión a un servidor web siguiendo las reglas de este protocolo para solicitar un documento y mostrar lo que el servidor nos devuelve. El documento al que accederemos se encuentra en la página web https://www.w3.org/TR/PNG/iso_8859-1.txt

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('www.w3.org',80))
cmd = 'GET https://www.w3.org/TR/PNG/iso_8859-1.txt HTTP/1.0\r\n\r\n'.encode()

mysock.send(cmd)

while True:
    data = mysock.recv(512) #recv para recibir datos
    if len(data)<1:
        break
    print(data.decode())
    
mysock.close()
# Out:
# HTTP/1.1 200 OK
# date: Sun, 14 Mar 2021 16:21:00 GMT
# last-modified: Fri, 07 Nov 2003 05:51:11 GMT
# etag: "17e9-3cb82080711c0;50c0b26855880"
# accept-ranges: bytes
# content-length: 6121
# cache-control: max-age=31536000
# expires: Mon, 14 Mar 2022 16:21:00 GMT
# vary: Accept-Encoding,upgrade-insecure-requests
# access-control-allow-origin: *
# keep-alive: timeout=5, max=2000
# content-type: text/plain
# x-backend: www-mirrors
# connection: close
#
# The following are the graphical (non-control) characters defined by
#
# ISO 8859-1 (1987).  Descriptions in words aren't all that helpful,
# but they're the best we can do in text.  A graphics file illustrating
# the character set should be available from the same archive as this
# file.
#
# Hex Description                 Hex Description
#
# 20  SPACE
# 21  EXCLAMATION MARK            A1  INVERTED EXCLAMATION MARK
# 22  QUOTATION MARK              A2  CENT SIGN
# 23  NUMBER SIGN                 A3  POUND SIGN
# 24  DOLLAR SIGN                 A4  CURRENCY SIGN
# 25  PERCENT SIGN                A5
# YEN SIGN
# 26  AMPERSAND                   A6  BROKEN BAR
# 27  APOSTROPHE                  A7  SECTION SIGN
# 28  LEFT PARENTHESIS            A8  DIAERESIS
# 29  RIGHT PARENTHESIS           A9  COPYRIGHT SIGN
# 2A  ASTERISK                    AA  FEMININE ORDINAL INDICATOR
# 2B  PLUS SIGN                   AB  LEFT-POINTING DOUBLE ANGLE QUOTATION MARK
# 2C  COMMA                       AC  NOT SIGN
# 2D  HYPHEN-MINUS                AD  SOFT HYPHEN
# 2E  FULL STOP                   AE  REGISTERED SIGN
# 2F  SOLIDUS
#         AF  OVERLINE
# 30  DIGIT ZERO                  B0  DEGREE SIGN
# 31  DIGIT ONE                   B1  PLUS-MINUS SIGN
# 32  DIGIT TWO                   B2  SUPERSCRIPT TWO
# 33  DIGIT THREE                 B3  SUPERSCRIPT THREE
# 34  DIGIT FOUR                  B4  ACUTE ACCENT
# 35  DIGIT FIVE                  B5  MICRO SIGN
# 36  DIGIT SIX                   B6  PILCROW SIGN
# 37  DIGIT SEVEN                 B7  MIDDLE DOT
# 38  DIGIT EIGHT                 B8  CEDILLA
# 39  DIGIT NINE                  B9  SUPERSCRIPT O
# NE
# 3A  COLON                       BA  MASCULINE ORDINAL INDICATOR
# 3B  SEMICOLON                   BB  RIGHT-POINTING DOUBLE ANGLE QUOTATION MARK
# 3C  LESS-THAN SIGN              BC  VULGAR FRACTION ONE QUARTER
# 3D  EQUALS SIGN                 BD  VULGAR FRACTION ONE HALF
# 3E  GREATER-THAN SIGN           BE  VULGAR FRACTION THREE QUARTERS
# 3F  QUESTION MARK               BF  INVERTED QUESTION MARK
# 40  COMMERCIAL AT               C0  CAPITAL LETTER A WITH GRAVE
# 41  CAPITAL LETTER A            C1  CAPITAL LETTER
# A WITH ACUTE
# 42  CAPITAL LETTER B            C2  CAPITAL LETTER A WITH CIRCUMFLEX
# 43  CAPITAL LETTER C            C3  CAPITAL LETTER A WITH TILDE
# 44  CAPITAL LETTER D            C4  CAPITAL LETTER A WITH DIAERESIS
# 45  CAPITAL LETTER E            C5  CAPITAL LETTER A WITH RING ABOVE
# 46  CAPITAL LETTER F            C6  CAPITAL LETTER AE
# 47  CAPITAL LETTER G            C7  CAPITAL LETTER C WITH CEDILLA
# 48  CAPITAL LETTER H            C8  CAPITAL LETTER E WITH GRAVE
# 49  CAPITAL LETTER I            C9  CAPITAL L
# ETTER E WITH ACUTE
# 4A  CAPITAL LETTER J            CA  CAPITAL LETTER E WITH CIRCUMFLEX
# 4B  CAPITAL LETTER K            CB  CAPITAL LETTER E WITH DIAERESIS
# 4C  CAPITAL LETTER L            CC  CAPITAL LETTER I WITH GRAVE
# 4D  CAPITAL LETTER M            CD  CAPITAL LETTER I WITH ACUTE
# 4E  CAPITAL LETTER N            CE  CAPITAL LETTER I WITH CIRCUMFLEX
# 4F  CAPITAL LETTER O            CF  CAPITAL LETTER I WITH DIAERESIS
# 50  CAPITAL LETTER P            D0  CAPITAL LETTER ETH (Icelandic)
# 51  CAPITAL LETTER Q
#         D1  CAPITAL LETTER N WITH TILDE
# 52  CAPITAL LETTER R            D2  CAPITAL LETTER O WITH GRAVE
# 53  CAPITAL LETTER S            D3  CAPITAL LETTER O WITH ACUTE
# 54  CAPITAL LETTER T            D4  CAPITAL LETTER O WITH CIRCUMFLEX
# 55  CAPITAL LETTER U            D5  CAPITAL LETTER O WITH TILDE
# 56  CAPITAL LETTER V            D6  CAPITAL LETTER O WITH DIAERESIS
# 57  CAPITAL LETTER W            D7  MULTIPLICATION SIGN
# 58  CAPITAL LETTER X            D8  CAPITAL LETTER O WITH STROKE
# 59  CAPITAL LETTER Y
#           D9  CAPITAL LETTER U WITH GRAVE
# 5A  CAPITAL LETTER Z            DA  CAPITAL LETTER U WITH ACUTE
# 5B  LEFT SQUARE BRACKET         DB  CAPITAL LETTER U WITH CIRCUMFLEX
# 5C  REVERSE SOLIDUS             DC  CAPITAL LETTER U WITH DIAERESIS
# 5D  RIGHT SQUARE BRACKET        DD  CAPITAL LETTER Y WITH ACUTE
# 5E  CIRCUMFLEX ACCENT           DE  CAPITAL LETTER THORN (Icelandic)
# 5F  LOW LINE                    DF  SMALL LETTER SHARP S (German)
# 60  GRAVE ACCENT                E0  SMALL LETTER A WITH GRAVE
# 61  SMAL
# L LETTER A              E1  SMALL LETTER A WITH ACUTE
# 62  SMALL LETTER B              E2  SMALL LETTER A WITH CIRCUMFLEX
# 63  SMALL LETTER C              E3  SMALL LETTER A WITH TILDE
# 64  SMALL LETTER D              E4  SMALL LETTER A WITH DIAERESIS
# 65  SMALL LETTER E              E5  SMALL LETTER A WITH RING ABOVE
# 66  SMALL LETTER F              E6  SMALL LETTER AE
# 67  SMALL LETTER G              E7  SMALL LETTER C WITH CEDILLA
# 68  SMALL LETTER H              E8  SMALL LETTER E WITH GRAVE
# 69  SMALL LETTER I
#               E9  SMALL LETTER E WITH ACUTE
# 6A  SMALL LETTER J              EA  SMALL LETTER E WITH CIRCUMFLEX
# 6B  SMALL LETTER K              EB  SMALL LETTER E WITH DIAERESIS
# 6C  SMALL LETTER L              EC  SMALL LETTER I WITH GRAVE
# 6D  SMALL LETTER M              ED  SMALL LETTER I WITH ACUTE
# 6E  SMALL LETTER N              EE  SMALL LETTER I WITH CIRCUMFLEX
# 6F  SMALL LETTER O              EF  SMALL LETTER I WITH DIAERESIS
# 70  SMALL LETTER P              F0  SMALL LETTER ETH (Icelandic)
# 71  SMALL LET
# TER Q              F1  SMALL LETTER N WITH TILDE
# 72  SMALL LETTER R              F2  SMALL LETTER O WITH GRAVE
# 73  SMALL LETTER S              F3  SMALL LETTER O WITH ACUTE
# 74  SMALL LETTER T              F4  SMALL LETTER O WITH CIRCUMFLEX
# 75  SMALL LETTER U              F5  SMALL LETTER O WITH TILDE
# 76  SMALL LETTER V              F6  SMALL LETTER O WITH DIAERESIS
# 77  SMALL LETTER W              F7  DIVISION SIGN
# 78  SMALL LETTER X              F8  SMALL LETTER O WITH STROKE
# 79  SMALL LETTER Y
#  F9  SMALL LETTER U WITH GRAVE
# 7A  SMALL LETTER Z              FA  SMALL LETTER U WITH ACUTE
# 7B  LEFT CURLY BRACKET          FB  SMALL LETTER U WITH CIRCUMFLEX
# 7C  VERTICAL LINE               FC  SMALL LETTER U WITH DIAERESIS
# 7D  RIGHT CURLY BRACKET         FD  SMALL LETTER Y WITH ACUTE
# 7E  TILDE                       FE  SMALL LETTER THORN (Icelandic)
#                                 FF  SMALL LETTER Y WITH DIAERESIS

# %% [markdown]
# Primero, el programa realiza una conexión al puerto 80 del servidor www.w3.org. Como nuestro programa está asumiendo el rol de "navegador web", el protocolo HTTP nos dice que tenemos que enviar el comando GET seguido por una línea en blanco. `\r\n` significa un final de línea, y `\r\n\r\n` es el equivalente a la línea en blanco.

# %% [markdown]
# <a id="urllib"></a>
# ## Recepción de páginas web con urllib

# %%
# Lo mismo que lo anterior, pero más fácil con la librería urllib
import urllib.request

f = urllib.request.urlopen('https://www.w3.org/TR/PNG/iso_8859-1.txt')
for line in f:
    print (line.decode().strip())
# Out:
# The following are the graphical (non-control) characters defined by
# ISO 8859-1 (1987).  Descriptions in words aren't all that helpful,
# but they're the best we can do in text.  A graphics file illustrating
# the character set should be available from the same archive as this
# file.
#
# Hex Description                 Hex Description
#
# 20  SPACE
# 21  EXCLAMATION MARK            A1  INVERTED EXCLAMATION MARK
# 22  QUOTATION MARK              A2  CENT SIGN
# 23  NUMBER SIGN                 A3  POUND SIGN
# 24  DOLLAR SIGN                 A4  CURRENCY SIGN
# 25  PERCENT SIGN                A5  YEN SIGN
# 26  AMPERSAND                   A6  BROKEN BAR
# 27  APOSTROPHE                  A7  SECTION SIGN
# 28  LEFT PARENTHESIS            A8  DIAERESIS
# 29  RIGHT PARENTHESIS           A9  COPYRIGHT SIGN
# 2A  ASTERISK                    AA  FEMININE ORDINAL INDICATOR
# 2B  PLUS SIGN                   AB  LEFT-POINTING DOUBLE ANGLE QUOTATION MARK
# 2C  COMMA                       AC  NOT SIGN
# 2D  HYPHEN-MINUS                AD  SOFT HYPHEN
# 2E  FULL STOP                   AE  REGISTERED SIGN
# 2F  SOLIDUS                     AF  OVERLINE
# 30  DIGIT ZERO                  B0  DEGREE SIGN
# 31  DIGIT ONE                   B1  PLUS-MINUS SIGN
# 32  DIGIT TWO                   B2  SUPERSCRIPT TWO
# 33  DIGIT THREE                 B3  SUPERSCRIPT THREE
# 34  DIGIT FOUR                  B4  ACUTE ACCENT
# 35  DIGIT FIVE                  B5  MICRO SIGN
# 36  DIGIT SIX                   B6  PILCROW SIGN
# 37  DIGIT SEVEN                 B7  MIDDLE DOT
# 38  DIGIT EIGHT                 B8  CEDILLA
# 39  DIGIT NINE                  B9  SUPERSCRIPT ONE
# 3A  COLON                       BA  MASCULINE ORDINAL INDICATOR
# 3B  SEMICOLON                   BB  RIGHT-POINTING DOUBLE ANGLE QUOTATION MARK
# 3C  LESS-THAN SIGN              BC  VULGAR FRACTION ONE QUARTER
# 3D  EQUALS SIGN                 BD  VULGAR FRACTION ONE HALF
# 3E  GREATER-THAN SIGN           BE  VULGAR FRACTION THREE QUARTERS
# 3F  QUESTION MARK               BF  INVERTED QUESTION MARK
# 40  COMMERCIAL AT               C0  CAPITAL LETTER A WITH GRAVE
# 41  CAPITAL LETTER A            C1  CAPITAL LETTER A WITH ACUTE
# 42  CAPITAL LETTER B            C2  CAPITAL LETTER A WITH CIRCUMFLEX
# 43  CAPITAL LETTER C            C3  CAPITAL LETTER A WITH TILDE
# 44  CAPITAL LETTER D            C4  CAPITAL LETTER A WITH DIAERESIS
# 45  CAPITAL LETTER E            C5  CAPITAL LETTER A WITH RING ABOVE
# 46  CAPITAL LETTER F            C6  CAPITAL LETTER AE
# 47  CAPITAL LETTER G            C7  CAPITAL LETTER C WITH CEDILLA
# 48  CAPITAL LETTER H            C8  CAPITAL LETTER E WITH GRAVE
# 49  CAPITAL LETTER I            C9  CAPITAL LETTER E WITH ACUTE
# 4A  CAPITAL LETTER J            CA  CAPITAL LETTER E WITH CIRCUMFLEX
# 4B  CAPITAL LETTER K            CB  CAPITAL LETTER E WITH DIAERESIS
# 4C  CAPITAL LETTER L            CC  CAPITAL LETTER I WITH GRAVE
# 4D  CAPITAL LETTER M            CD  CAPITAL LETTER I WITH ACUTE
# 4E  CAPITAL LETTER N            CE  CAPITAL LETTER I WITH CIRCUMFLEX
# 4F  CAPITAL LETTER O            CF  CAPITAL LETTER I WITH DIAERESIS
# 50  CAPITAL LETTER P            D0  CAPITAL LETTER ETH (Icelandic)
# 51  CAPITAL LETTER Q            D1  CAPITAL LETTER N WITH TILDE
# 52  CAPITAL LETTER R            D2  CAPITAL LETTER O WITH GRAVE
# 53  CAPITAL LETTER S            D3  CAPITAL LETTER O WITH ACUTE
# 54  CAPITAL LETTER T            D4  CAPITAL LETTER O WITH CIRCUMFLEX
# 55  CAPITAL LETTER U            D5  CAPITAL LETTER O WITH TILDE
# 56  CAPITAL LETTER V            D6  CAPITAL LETTER O WITH DIAERESIS
# 57  CAPITAL LETTER W            D7  MULTIPLICATION SIGN
# 58  CAPITAL LETTER X            D8  CAPITAL LETTER O WITH STROKE
# 59  CAPITAL LETTER Y            D9  CAPITAL LETTER U WITH GRAVE
# 5A  CAPITAL LETTER Z            DA  CAPITAL LETTER U WITH ACUTE
# 5B  LEFT SQUARE BRACKET         DB  CAPITAL LETTER U WITH CIRCUMFLEX
# 5C  REVERSE SOLIDUS             DC  CAPITAL LETTER U WITH DIAERESIS
# 5D  RIGHT SQUARE BRACKET        DD  CAPITAL LETTER Y WITH ACUTE
# 5E  CIRCUMFLEX ACCENT           DE  CAPITAL LETTER THORN (Icelandic)
# 5F  LOW LINE                    DF  SMALL LETTER SHARP S (German)
# 60  GRAVE ACCENT                E0  SMALL LETTER A WITH GRAVE
# 61  SMALL LETTER A              E1  SMALL LETTER A WITH ACUTE
# 62  SMALL LETTER B              E2  SMALL LETTER A WITH CIRCUMFLEX
# 63  SMALL LETTER C              E3  SMALL LETTER A WITH TILDE
# 64  SMALL LETTER D              E4  SMALL LETTER A WITH DIAERESIS
# 65  SMALL LETTER E              E5  SMALL LETTER A WITH RING ABOVE
# 66  SMALL LETTER F              E6  SMALL LETTER AE
# 67  SMALL LETTER G              E7  SMALL LETTER C WITH CEDILLA
# 68  SMALL LETTER H              E8  SMALL LETTER E WITH GRAVE
# 69  SMALL LETTER I              E9  SMALL LETTER E WITH ACUTE
# 6A  SMALL LETTER J              EA  SMALL LETTER E WITH CIRCUMFLEX
# 6B  SMALL LETTER K              EB  SMALL LETTER E WITH DIAERESIS
# 6C  SMALL LETTER L              EC  SMALL LETTER I WITH GRAVE
# 6D  SMALL LETTER M              ED  SMALL LETTER I WITH ACUTE
# 6E  SMALL LETTER N              EE  SMALL LETTER I WITH CIRCUMFLEX
# 6F  SMALL LETTER O              EF  SMALL LETTER I WITH DIAERESIS
# 70  SMALL LETTER P              F0  SMALL LETTER ETH (Icelandic)
# 71  SMALL LETTER Q              F1  SMALL LETTER N WITH TILDE
# 72  SMALL LETTER R              F2  SMALL LETTER O WITH GRAVE
# 73  SMALL LETTER S              F3  SMALL LETTER O WITH ACUTE
# 74  SMALL LETTER T              F4  SMALL LETTER O WITH CIRCUMFLEX
# 75  SMALL LETTER U              F5  SMALL LETTER O WITH TILDE
# 76  SMALL LETTER V              F6  SMALL LETTER O WITH DIAERESIS
# 77  SMALL LETTER W              F7  DIVISION SIGN
# 78  SMALL LETTER X              F8  SMALL LETTER O WITH STROKE
# 79  SMALL LETTER Y              F9  SMALL LETTER U WITH GRAVE
# 7A  SMALL LETTER Z              FA  SMALL LETTER U WITH ACUTE
# 7B  LEFT CURLY BRACKET          FB  SMALL LETTER U WITH CIRCUMFLEX
# 7C  VERTICAL LINE               FC  SMALL LETTER U WITH DIAERESIS
# 7D  RIGHT CURLY BRACKET         FD  SMALL LETTER Y WITH ACUTE
# 7E  TILDE                       FE  SMALL LETTER THORN (Icelandic)
# FF  SMALL LETTER Y WITH DIAERESIS

# %% [markdown]
# Cuando el programa se ejecuta, en su salida sólo vemos el contenido del fichero. Las cabeceras siguen enviándose, pero el código de `urllib` se queda con ella y sólo nos devuelve los datos. Una vez abierta la página web, se puede leer como si fuese un archivo local.
# ¿Qué ocurre si cambiamos el txt por otra página web?

# %% [markdown]
# <a id="bea"></a>
# ## Parsing de HTML mediante BeatifulSoup

# %% [markdown]
# BeautifulSoup es una librería de Python que permite analizar documentos HTML y extraer datos de ellos, compensando imperfecciones que puedan existir. Para instalar esta librería escribimos en anaconda Prompt:
# `conda install -c anaconda beautifulsoup4`

# %% [markdown]
# Esta librería permite, por ejemplo, extraer los atributos href de las etiquetas de anclaje (a)
# <img src='http://www.cellbiol.com/bioinformatics_web_development/wp-content/uploads/2017/01/attributes_and_values_in_the_a_tag.png'>
# En el siguiente ejemplo, vamos a parsear una entrada HTML y extraer los links utilizando la librería BeautifulSoup.
# Utilizaremos urllib para leer la página y después BeautifulSoup para extraer los atributos href de las etiquetas de tipo ancla (a)

# %%
import urllib
from bs4 import BeautifulSoup

url = input('Enter URL: ')
html = urllib.request.urlopen(url)

soup = BeautifulSoup(html)

tags = soup('a')

for tag in tags:
    print(tag.get('href'))
# Out:
# Enter URL:  https://www.eoi.es/
# #main-content
# /contacto
# http://www.eoi.es/portal/en
# /en
# /es
# /es
# /business-school
# /mbas-masters
# /programas/programas-ejecutivos
# /programas/programas-enfocados
# /programas/cursos-talleres-seminarios
# /programas/admisiones
# /programas/becas-y-descuentos
# https://www.eoi.es/es/programas/estilo-propio
# /es/metodologia
# /es/rankings
# /programas/talentia360-mujeres-directivas
# /es/programas/secretaria
# /empresas
# /empresas/company
# /empresas/pymes
# /es/inmersiondigitalindustriacovid19
# https://www.eoi.es/es/aceleracionmarketingdigitalturismo
# /empresas/pymes/cursos
# /empresas/pymes/ayudas-la-contratacion
# https://www.eoi.es/es/ayudas-practicas-no-laborales
# /empresas/pymes/digitalxborder
# /empresas/emprendedores
# /empresas/emprendedores/espacios-coworking
# /empresas/emprendedores/ayudas-al-emprendimiento
# /circularlabs
# /empresas/emprendedores/low-carbon-innovation
# /empresas/emprendedores/red-agriconect-40
# /empresas/emprendedores/crafts-code
# /empresas/emprendedores/crafting-europe
# /es/empresas/emprendedores/iniciativa-emprendedora
# /empresas/emprendedores/12-retos-de-industria-40
# /empresas/activa-industria-40
# /activaciberseguridad
# /empresas/activa-crecimiento
# https://www.eoi.es/es/empleo
# /empresas/empleo-joven
# /empresas/empleo-joven/formacion-para-el-empleo-joven
# /empresas/empleo-joven/plataforma-de-empleo-eoi-social
# /cursos/34118/curso-de-transformacion-digital-para-el-empleo-ambito-nacional-3a-edicion
# /empleo/desempleados-de-larga-duracion
# /empleo/desempleados-de-larga-duracion/formacion-para-desempleados-de-larga-duracion
# /empleo/desempleados-de-larga-duracion/emprendimiento-para-desempleados-de-larga-duracion
# /cursos/35580/programa-talento-digital-ambito-nacional
# /investigacion
# /investigacion/publicaciones
# /savia
# /investigacion/biblioteca
# /investigacion/estructura-de-la-catedra
# /investigacion/observatorio-de-prospectiva-tecnologica-industrial
# /es/alumni
# /es/alumni/alumni-practicas
# /es/alumni/carreras-profesionales
# /clubeoi
# /es/observatorioeconomiaglobal
# /es/alumni/gestores-del-cambio
# /es/conocenos/historia
# /es/conocenos/historia
# /es/conocenos/quienes-somos
# /es/agenda2030-ODS
# /es/conocenos/internacional
# /es/conocenos/internacional
# /es/conocenos/internacional/programas-internacionales
# /es/conocenos/internacional/european-coworking
# /es/conocenos/internacional/redtikal
# /es/conocenos/internacional/otros-proyectos-internacionales
# /es/conocenos/colegios-mayores
# /es/conocenos/fundesarte
# /es/conocenos/sedes
# /es/conocenos/entidades-colaboradoras
# /es/conocenos/transparencia
# /es/conocenos/centro-de-referencia-nacional
# /es/conocenos/perfil-de-contratante
# /actualidad
# /actualidad
# /es/actualidad/sala-de-prensa
# /es/actualidad/identidad-corporativa
# /es/actualidad/redes-sociales
# /es/actualidad/television
# https://www.eoi.es/search
# https://www.eoi.es/es/agenda2030-ODS
# https://www.eoi.es/es/noticias/eoi-entre-las-10-universidades-y-escuelas-de-negocio-iberoamericanas-mas-innovadoras
# https://www.eoi.es/es/volvemos-covid19
# https://www.eoi.es/es/becas/34714/descuentos-para-nuevos-lideres-digitales
# /es/noticias/33705/eoi-se-consolida-como-lider-en-formacion-medioambiental-en-espana
# /es/noticias/32543/el-master-en-big-data-de-eoi-destaca-en-el-ranking-qs-por-su-retorno-de-inversion-un-25-superior-la-media-internacional
# #carousel-example-2
# #carousel-example-2
# /programas/programas-executive
# /programas/mbas-masters
# https://www.eoi.es/es/digital-learning
# /empresas
# /es/conocenos/internacional
# /savia
# /es/conocenos/historia
# https://www.eoi.es/es/clubeoi/eventos/35721/taller-nuestro-cv-quienes-somos-y-que-aportamos-club-eoi-aforo-completo
# https://www.eoi.es/es/eventos/35792/taller-storytelling-para-emprendedores-coworking-malaga
# https://www.eoi.es/es/eventos/35773/webinar-tomar-decisiones-basadas-en-datos-aplicaciones-de-talent-analytics
# https://www.eoi.es/es/clubeoi/eventos/35725/taller-gestion-de-la-incertidumbre-traves-de-mindfulness-online
# https://www.eoi.es/es/eventos/35763/webinar-la-revolucion-de-iot-y-5g
# #theCarousel_317833015
# #theCarousel_317833015
# https://www.eoi.es/actualidad
# /es/cursos/35505/programa-ejecutivo-en-smart-energy-madrid
# /es/cursos/33289/programa-de-desarrollo-para-la-direccion-mujeres-con-alto-potencial-madrid
# /es/cursos/16532/executive-mba-online
# /programas/admisiones
# /programas/becas-y-ayudas
# /conocenos/colegios-mayores
# /es/conocenos/sedes
# https://www.eoi.es/sites/default/files/inline-files/Certificado_9001.pdf
# https://www.eoi.es/sites/default/files/inline-files/Certificado_14001.pdf
# https://www.eoi.es/sites/default/files/inline-files/Certificado_45001.pdf
# /programas
# /mbas-masters
# /programas/programas-ejecutivos
# /programas/programas-enfocados
# /admisiones
# /programas/cursos-talleres-seminarios
# /becas-y-ayudas
# /es/metodologia
# /programas/programas-enfocados
# /empresas
# /in-company
# /pymes
# /es/emprendimiento
# /acuerdos
# /investigacion
# /publicaciones
# /repositorio-savia
# /es/biblioteca
# /catedra-eoi-oepm
# /opti
# /es/alumni
# /es/alumni/alumni-practicas
# /es/alumni/carreras-profesionales
# /club-eoi
# /conocenos
# /es/conocenos/quienes-somos
# /es/conocenos/fundesarte
# /es/conocenos/internacional
# /es/conocenos/sedes
# /es/conocenos/colegios-mayores
# /es/conocenos/transparencia
# /actualidad
# /agenda
# /sala-de-prensa
# /identidad-corporativa
# /blogs
# /redes-sociales
# https://www.twitter.com/eoi
# https://www.facebook.com/eoi.edu
# https://www.linkedin.com/school/eoi/
# https://www.youtube.com/user/eoimedia
# https://www.flickr.com/photos/eoi/
# https://www.instagram.com/eoischool/
# /es/conocenos/perfil-de-contratante
# /es/aviso-legal
# /es/politica-de-privacidad
# /es/politica-de-cookies

# %% [markdown]
# Podemos extraer más campos de las etiquetas

# %%
import urllib
from bs4 import BeautifulSoup

url = input('Enter URL: ')
html = urllib.request.urlopen(url)

soup = BeautifulSoup(html)

tags = soup('a')

for tag in tags:
    print('TAG:', tag)
    print('URL:', tag.get('href'))
    print('Text:', tag.contents)
    print('Attributes:', tag.attrs)
    print('\n')
# Out:
# Enter URL:  https://www.eoi.es
# TAG: <a class="visually-hidden focusable" href="#main-content">
#       Pasar al contenido principal
#     </a>
# URL: #main-content
# Text: ['\n      Pasar al contenido principal\n    ']
# Attributes: {'href': '#main-content', 'class': ['visually-hidden', 'focusable']}
#
#
# TAG: <a aria-label="Contacto" href="/contacto" title="Contacto">Contacto</a>
# URL: /contacto
# Text: ['Contacto']
# Attributes: {'href': '/contacto', 'aria-label': 'Contacto', 'title': 'Contacto'}
#
#
# TAG: <a aria-label="English" href="http://www.eoi.es/portal/en" title="English">English</a>
# URL: http://www.eoi.es/portal/en
# Text: ['English']
# Attributes: {'href': 'http://www.eoi.es/portal/en', 'aria-label': 'English', 'title': 'English'}
#
#
# TAG: <a class="language-link" data-drupal-link-system-path="&lt;front&gt;" href="/en" hreflang="en">English</a>
# URL: /en
# Text: ['English']
# Attributes: {'href': '/en', 'class': ['language-link'], 'hreflang': 'en', 'data-drupal-link-system-path': '<front>'}
#
#
# TAG: <a class="language-link is-active" data-drupal-link-system-path="&lt;front&gt;" href="/es" hreflang="es">Español</a>
# URL: /es
# Text: ['Español']
# Attributes: {'href': '/es', 'class': ['language-link', 'is-active'], 'hreflang': 'es', 'data-drupal-link-system-path': '<front>'}
#
#
# TAG: <a aria-label="" class="navbar-brand d-flex align-items-center" href="/es">
# <img alt="EOI logo" class="mr-2" height="auto" src="/sites/default/files/logo-eoi.png" width="170"/>
# </a>
# URL: /es
# Text: ['\n', <img alt="EOI logo" class="mr-2" height="auto" src="/sites/default/files/logo-eoi.png" width="170"/>, '\n']
# Attributes: {'href': '/es', 'class': ['navbar-brand', 'd-flex', 'align-items-center'], 'aria-label': ''}
#
#
# TAG: <a class="sf-depth-1 main-menu-item-items-child menuparent" href="/business-school">Programas</a>
# URL: /business-school
# Text: ['Programas']
# Attributes: {'href': '/business-school', 'class': ['sf-depth-1', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/mbas-masters">MBAs &amp; Masters</a>
# URL: /mbas-masters
# Text: ['MBAs & Masters']
# Attributes: {'href': '/mbas-masters', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/programas/programas-ejecutivos">Programas Ejecutivos</a>
# URL: /programas/programas-ejecutivos
# Text: ['Programas Ejecutivos']
# Attributes: {'href': '/programas/programas-ejecutivos', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/programas/programas-enfocados">Programas Enfocados</a>
# URL: /programas/programas-enfocados
# Text: ['Programas Enfocados']
# Attributes: {'href': '/programas/programas-enfocados', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/programas/cursos-talleres-seminarios">Cursos, Talleres y Seminarios</a>
# URL: /programas/cursos-talleres-seminarios
# Text: ['Cursos, Talleres y Seminarios']
# Attributes: {'href': '/programas/cursos-talleres-seminarios', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/programas/admisiones">Admisiones</a>
# URL: /programas/admisiones
# Text: ['Admisiones']
# Attributes: {'href': '/programas/admisiones', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/programas/becas-y-descuentos">Becas y Descuentos</a>
# URL: /programas/becas-y-descuentos
# Text: ['Becas y Descuentos']
# Attributes: {'href': '/programas/becas-y-descuentos', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child sf-external" href="https://www.eoi.es/es/programas/estilo-propio">Estilo Propio</a>
# URL: https://www.eoi.es/es/programas/estilo-propio
# Text: ['Estilo Propio']
# Attributes: {'href': 'https://www.eoi.es/es/programas/estilo-propio', 'class': ['sf-depth-2', 'main-menu-item-items-child', 'sf-external']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/metodologia">Metodología</a>
# URL: /es/metodologia
# Text: ['Metodología']
# Attributes: {'href': '/es/metodologia', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/rankings">Rankings</a>
# URL: /es/rankings
# Text: ['Rankings']
# Attributes: {'href': '/es/rankings', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/programas/talentia360-mujeres-directivas">Talentia360. Mujeres Directivas</a>
# URL: /programas/talentia360-mujeres-directivas
# Text: ['Talentia360. Mujeres Directivas']
# Attributes: {'href': '/programas/talentia360-mujeres-directivas', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/programas/secretaria">Secretaría</a>
# URL: /es/programas/secretaria
# Text: ['Secretaría']
# Attributes: {'href': '/es/programas/secretaria', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-1 main-menu-item-items-child menuparent" href="/empresas">Empresas</a>
# URL: /empresas
# Text: ['Empresas']
# Attributes: {'href': '/empresas', 'class': ['sf-depth-1', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/empresas/company">In company</a>
# URL: /empresas/company
# Text: ['In company']
# Attributes: {'href': '/empresas/company', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child menuparent" href="/empresas/pymes">Pymes</a>
# URL: /empresas/pymes
# Text: ['Pymes']
# Attributes: {'href': '/empresas/pymes', 'class': ['sf-depth-2', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/es/inmersiondigitalindustriacovid19">Inmersión Digital Industria COVID-19</a>
# URL: /es/inmersiondigitalindustriacovid19
# Text: ['Inmersión Digital Industria COVID-19']
# Attributes: {'href': '/es/inmersiondigitalindustriacovid19', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child sf-external" href="https://www.eoi.es/es/aceleracionmarketingdigitalturismo">Aceleración Marketing Digital Turismo</a>
# URL: https://www.eoi.es/es/aceleracionmarketingdigitalturismo
# Text: ['Aceleración Marketing Digital Turismo']
# Attributes: {'href': 'https://www.eoi.es/es/aceleracionmarketingdigitalturismo', 'class': ['sf-depth-3', 'main-menu-item-items-child', 'sf-external']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/pymes/cursos">Cursos</a>
# URL: /empresas/pymes/cursos
# Text: ['Cursos']
# Attributes: {'href': '/empresas/pymes/cursos', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/pymes/ayudas-la-contratacion">Ayudas a la contratación</a>
# URL: /empresas/pymes/ayudas-la-contratacion
# Text: ['Ayudas a la contratación']
# Attributes: {'href': '/empresas/pymes/ayudas-la-contratacion', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child sf-external" href="https://www.eoi.es/es/ayudas-practicas-no-laborales">Ayudas Prácticas No Laborales</a>
# URL: https://www.eoi.es/es/ayudas-practicas-no-laborales
# Text: ['Ayudas Prácticas No Laborales']
# Attributes: {'href': 'https://www.eoi.es/es/ayudas-practicas-no-laborales', 'class': ['sf-depth-3', 'main-menu-item-items-child', 'sf-external']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/pymes/digitalxborder">Digitalxborder</a>
# URL: /empresas/pymes/digitalxborder
# Text: ['Digitalxborder']
# Attributes: {'href': '/empresas/pymes/digitalxborder', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child menuparent" href="/empresas/emprendedores">Emprendedores</a>
# URL: /empresas/emprendedores
# Text: ['Emprendedores']
# Attributes: {'href': '/empresas/emprendedores', 'class': ['sf-depth-2', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/emprendedores/espacios-coworking">Espacios coworking</a>
# URL: /empresas/emprendedores/espacios-coworking
# Text: ['Espacios coworking']
# Attributes: {'href': '/empresas/emprendedores/espacios-coworking', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/emprendedores/ayudas-al-emprendimiento">Ayudas al emprendimiento</a>
# URL: /empresas/emprendedores/ayudas-al-emprendimiento
# Text: ['Ayudas al emprendimiento']
# Attributes: {'href': '/empresas/emprendedores/ayudas-al-emprendimiento', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/circularlabs">Circular labs</a>
# URL: /circularlabs
# Text: ['Circular labs']
# Attributes: {'href': '/circularlabs', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/emprendedores/low-carbon-innovation">Low Carbon Innovation</a>
# URL: /empresas/emprendedores/low-carbon-innovation
# Text: ['Low Carbon Innovation']
# Attributes: {'href': '/empresas/emprendedores/low-carbon-innovation', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/emprendedores/red-agriconect-40">Red Agriconect 4.0</a>
# URL: /empresas/emprendedores/red-agriconect-40
# Text: ['Red Agriconect 4.0']
# Attributes: {'href': '/empresas/emprendedores/red-agriconect-40', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/emprendedores/crafts-code">Crafts Code</a>
# URL: /empresas/emprendedores/crafts-code
# Text: ['Crafts Code']
# Attributes: {'href': '/empresas/emprendedores/crafts-code', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/emprendedores/crafting-europe">Crafting Europe</a>
# URL: /empresas/emprendedores/crafting-europe
# Text: ['Crafting Europe']
# Attributes: {'href': '/empresas/emprendedores/crafting-europe', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/es/empresas/emprendedores/iniciativa-emprendedora">Desafío emprendimiento juvenil</a>
# URL: /es/empresas/emprendedores/iniciativa-emprendedora
# Text: ['Desafío emprendimiento juvenil']
# Attributes: {'href': '/es/empresas/emprendedores/iniciativa-emprendedora', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/emprendedores/12-retos-de-industria-40">12 retos industria 4.0</a>
# URL: /empresas/emprendedores/12-retos-de-industria-40
# Text: ['12 retos industria 4.0']
# Attributes: {'href': '/empresas/emprendedores/12-retos-de-industria-40', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/empresas/activa-industria-40">Activa Industria 4.0</a>
# URL: /empresas/activa-industria-40
# Text: ['Activa Industria 4.0']
# Attributes: {'href': '/empresas/activa-industria-40', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/activaciberseguridad">Activa Ciberseguridad</a>
# URL: /activaciberseguridad
# Text: ['Activa Ciberseguridad']
# Attributes: {'href': '/activaciberseguridad', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/empresas/activa-crecimiento">Activa Crecimiento</a>
# URL: /empresas/activa-crecimiento
# Text: ['Activa Crecimiento']
# Attributes: {'href': '/empresas/activa-crecimiento', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-1 main-menu-item-items-child sf-external menuparent" href="https://www.eoi.es/es/empleo">Empleo</a>
# URL: https://www.eoi.es/es/empleo
# Text: ['Empleo']
# Attributes: {'href': 'https://www.eoi.es/es/empleo', 'class': ['sf-depth-1', 'main-menu-item-items-child', 'sf-external', 'menuparent']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child menuparent" href="/empresas/empleo-joven">Empleo joven</a>
# URL: /empresas/empleo-joven
# Text: ['Empleo joven']
# Attributes: {'href': '/empresas/empleo-joven', 'class': ['sf-depth-2', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/empleo-joven/formacion-para-el-empleo-joven">Formación</a>
# URL: /empresas/empleo-joven/formacion-para-el-empleo-joven
# Text: ['Formación']
# Attributes: {'href': '/empresas/empleo-joven/formacion-para-el-empleo-joven', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empresas/empleo-joven/plataforma-de-empleo-eoi-social">Empleo</a>
# URL: /empresas/empleo-joven/plataforma-de-empleo-eoi-social
# Text: ['Empleo']
# Attributes: {'href': '/empresas/empleo-joven/plataforma-de-empleo-eoi-social', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/cursos/34118/curso-de-transformacion-digital-para-el-empleo-ambito-nacional-3a-edicion">Transformación digital</a>
# URL: /cursos/34118/curso-de-transformacion-digital-para-el-empleo-ambito-nacional-3a-edicion
# Text: ['Transformación digital']
# Attributes: {'href': '/cursos/34118/curso-de-transformacion-digital-para-el-empleo-ambito-nacional-3a-edicion', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child menuparent" href="/empleo/desempleados-de-larga-duracion">Desempleados de Larga Duración</a>
# URL: /empleo/desempleados-de-larga-duracion
# Text: ['Desempleados de Larga Duración']
# Attributes: {'href': '/empleo/desempleados-de-larga-duracion', 'class': ['sf-depth-2', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empleo/desempleados-de-larga-duracion/formacion-para-desempleados-de-larga-duracion">Formación</a>
# URL: /empleo/desempleados-de-larga-duracion/formacion-para-desempleados-de-larga-duracion
# Text: ['Formación']
# Attributes: {'href': '/empleo/desempleados-de-larga-duracion/formacion-para-desempleados-de-larga-duracion', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/empleo/desempleados-de-larga-duracion/emprendimiento-para-desempleados-de-larga-duracion">Emprendimiento</a>
# URL: /empleo/desempleados-de-larga-duracion/emprendimiento-para-desempleados-de-larga-duracion
# Text: ['Emprendimiento']
# Attributes: {'href': '/empleo/desempleados-de-larga-duracion/emprendimiento-para-desempleados-de-larga-duracion', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/cursos/35580/programa-talento-digital-ambito-nacional">Programa Talento Digital</a>
# URL: /cursos/35580/programa-talento-digital-ambito-nacional
# Text: ['Programa Talento Digital']
# Attributes: {'href': '/cursos/35580/programa-talento-digital-ambito-nacional', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-1 main-menu-item-items-child menuparent" href="/investigacion">Investigación</a>
# URL: /investigacion
# Text: ['Investigación']
# Attributes: {'href': '/investigacion', 'class': ['sf-depth-1', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/investigacion/publicaciones">Publicaciones</a>
# URL: /investigacion/publicaciones
# Text: ['Publicaciones']
# Attributes: {'href': '/investigacion/publicaciones', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/savia">Repositorio savia</a>
# URL: /savia
# Text: ['Repositorio savia']
# Attributes: {'href': '/savia', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/investigacion/biblioteca">Biblioteca</a>
# URL: /investigacion/biblioteca
# Text: ['Biblioteca']
# Attributes: {'href': '/investigacion/biblioteca', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/investigacion/estructura-de-la-catedra">Cátedra EOI OEPM</a>
# URL: /investigacion/estructura-de-la-catedra
# Text: ['Cátedra EOI OEPM']
# Attributes: {'href': '/investigacion/estructura-de-la-catedra', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/investigacion/observatorio-de-prospectiva-tecnologica-industrial">OPTI</a>
# URL: /investigacion/observatorio-de-prospectiva-tecnologica-industrial
# Text: ['OPTI']
# Attributes: {'href': '/investigacion/observatorio-de-prospectiva-tecnologica-industrial', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-1 main-menu-item-items-child menuparent" href="/es/alumni">Alumni</a>
# URL: /es/alumni
# Text: ['Alumni']
# Attributes: {'href': '/es/alumni', 'class': ['sf-depth-1', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/alumni/alumni-practicas">Prácticas</a>
# URL: /es/alumni/alumni-practicas
# Text: ['Prácticas']
# Attributes: {'href': '/es/alumni/alumni-practicas', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/alumni/carreras-profesionales">Carreras profesionales</a>
# URL: /es/alumni/carreras-profesionales
# Text: ['Carreras profesionales']
# Attributes: {'href': '/es/alumni/carreras-profesionales', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/clubeoi">Club EOI</a>
# URL: /clubeoi
# Text: ['Club EOI']
# Attributes: {'href': '/clubeoi', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/observatorioeconomiaglobal">Observatorio Economía Global</a>
# URL: /es/observatorioeconomiaglobal
# Text: ['Observatorio Economía Global']
# Attributes: {'href': '/es/observatorioeconomiaglobal', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/alumni/gestores-del-cambio">Gestores del cambio</a>
# URL: /es/alumni/gestores-del-cambio
# Text: ['Gestores del cambio']
# Attributes: {'href': '/es/alumni/gestores-del-cambio', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-1 main-menu-item-items-child menuparent" href="/es/conocenos/historia">Conócenos</a>
# URL: /es/conocenos/historia
# Text: ['Conócenos']
# Attributes: {'href': '/es/conocenos/historia', 'class': ['sf-depth-1', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/conocenos/historia">Qué es EOI</a>
# URL: /es/conocenos/historia
# Text: ['Qué es EOI']
# Attributes: {'href': '/es/conocenos/historia', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/conocenos/quienes-somos">Quiénes Somos </a>
# URL: /es/conocenos/quienes-somos
# Text: ['Quiénes Somos ']
# Attributes: {'href': '/es/conocenos/quienes-somos', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/agenda2030-ODS">Agenda 2030 -ODS</a>
# URL: /es/agenda2030-ODS
# Text: ['Agenda 2030 -ODS']
# Attributes: {'href': '/es/agenda2030-ODS', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child menuparent" href="/es/conocenos/internacional">Internacional</a>
# URL: /es/conocenos/internacional
# Text: ['Internacional']
# Attributes: {'href': '/es/conocenos/internacional', 'class': ['sf-depth-2', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/es/conocenos/internacional">Espíritu internacional</a>
# URL: /es/conocenos/internacional
# Text: ['Espíritu internacional']
# Attributes: {'href': '/es/conocenos/internacional', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/es/conocenos/internacional/programas-internacionales">Programas internacionales</a>
# URL: /es/conocenos/internacional/programas-internacionales
# Text: ['Programas internacionales']
# Attributes: {'href': '/es/conocenos/internacional/programas-internacionales', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/es/conocenos/internacional/european-coworking">European coworking</a>
# URL: /es/conocenos/internacional/european-coworking
# Text: ['European coworking']
# Attributes: {'href': '/es/conocenos/internacional/european-coworking', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/es/conocenos/internacional/redtikal">Red internacional: REDTIKAL</a>
# URL: /es/conocenos/internacional/redtikal
# Text: ['Red internacional: REDTIKAL']
# Attributes: {'href': '/es/conocenos/internacional/redtikal', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-3 main-menu-item-items-child" href="/es/conocenos/internacional/otros-proyectos-internacionales">Otros proyectos internacionales</a>
# URL: /es/conocenos/internacional/otros-proyectos-internacionales
# Text: ['Otros proyectos internacionales']
# Attributes: {'href': '/es/conocenos/internacional/otros-proyectos-internacionales', 'class': ['sf-depth-3', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/conocenos/colegios-mayores" title="Colegios Mayores">Colegios Mayores</a>
# URL: /es/conocenos/colegios-mayores
# Text: ['Colegios Mayores']
# Attributes: {'href': '/es/conocenos/colegios-mayores', 'title': 'Colegios Mayores', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/conocenos/fundesarte">Fundesarte</a>
# URL: /es/conocenos/fundesarte
# Text: ['Fundesarte']
# Attributes: {'href': '/es/conocenos/fundesarte', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/conocenos/sedes">Sedes</a>
# URL: /es/conocenos/sedes
# Text: ['Sedes']
# Attributes: {'href': '/es/conocenos/sedes', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/conocenos/entidades-colaboradoras">Entidades Colaboradoras</a>
# URL: /es/conocenos/entidades-colaboradoras
# Text: ['Entidades Colaboradoras']
# Attributes: {'href': '/es/conocenos/entidades-colaboradoras', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/conocenos/transparencia">Transparencia</a>
# URL: /es/conocenos/transparencia
# Text: ['Transparencia']
# Attributes: {'href': '/es/conocenos/transparencia', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/conocenos/centro-de-referencia-nacional">Centro de Referencia Nacional</a>
# URL: /es/conocenos/centro-de-referencia-nacional
# Text: ['Centro de Referencia Nacional']
# Attributes: {'href': '/es/conocenos/centro-de-referencia-nacional', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/conocenos/perfil-de-contratante">Perfil del Contratante</a>
# URL: /es/conocenos/perfil-de-contratante
# Text: ['Perfil del Contratante']
# Attributes: {'href': '/es/conocenos/perfil-de-contratante', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-1 main-menu-item-items-child menuparent" href="/actualidad">Actualidad</a>
# URL: /actualidad
# Text: ['Actualidad']
# Attributes: {'href': '/actualidad', 'class': ['sf-depth-1', 'main-menu-item-items-child', 'menuparent']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/actualidad">Agenda</a>
# URL: /actualidad
# Text: ['Agenda']
# Attributes: {'href': '/actualidad', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/actualidad/sala-de-prensa">Sala de prensa</a>
# URL: /es/actualidad/sala-de-prensa
# Text: ['Sala de prensa']
# Attributes: {'href': '/es/actualidad/sala-de-prensa', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/actualidad/identidad-corporativa">Identidad corporativa</a>
# URL: /es/actualidad/identidad-corporativa
# Text: ['Identidad corporativa']
# Attributes: {'href': '/es/actualidad/identidad-corporativa', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/actualidad/redes-sociales">Redes sociales</a>
# URL: /es/actualidad/redes-sociales
# Text: ['Redes sociales']
# Attributes: {'href': '/es/actualidad/redes-sociales', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a class="sf-depth-2 main-menu-item-items-child" href="/es/actualidad/television">Programas en TVE</a>
# URL: /es/actualidad/television
# Text: ['Programas en TVE']
# Attributes: {'href': '/es/actualidad/television', 'class': ['sf-depth-2', 'main-menu-item-items-child']}
#
#
# TAG: <a aria-label="Search Button Icon" class="search-icon-button" href="https://www.eoi.es/search" title="Search Button Icon">
# <i class="fas fa-search"></i>
# <span class="sr-only">Links, Opens in this window a searcher</span>
# </a>
# URL: https://www.eoi.es/search
# Text: ['\n', <i class="fas fa-search"></i>, '\n', <span class="sr-only">Links, Opens in this window a searcher</span>, '\n']
# Attributes: {'class': ['search-icon-button'], 'href': 'https://www.eoi.es/search', 'aria-label': 'Search Button Icon', 'title': 'Search Button Icon'}
#
#
# TAG: <a href="https://www.eoi.es/es/agenda2030-ODS">MÁS INFORMACIÓN</a>
# URL: https://www.eoi.es/es/agenda2030-ODS
# Text: ['MÁS INFORMACIÓN']
# Attributes: {'href': 'https://www.eoi.es/es/agenda2030-ODS'}
#
#
# TAG: <a href="https://www.eoi.es/es/noticias/eoi-entre-las-10-universidades-y-escuelas-de-negocio-iberoamericanas-mas-innovadoras">MÁS INFORMACIÓN</a>
# URL: https://www.eoi.es/es/noticias/eoi-entre-las-10-universidades-y-escuelas-de-negocio-iberoamericanas-mas-innovadoras
# Text: ['MÁS INFORMACIÓN']
# Attributes: {'href': 'https://www.eoi.es/es/noticias/eoi-entre-las-10-universidades-y-escuelas-de-negocio-iberoamericanas-mas-innovadoras'}
#
#
# TAG: <a href="https://www.eoi.es/es/volvemos-covid19">MÁS INFORMACIÓN</a>
# URL: https://www.eoi.es/es/volvemos-covid19
# Text: ['MÁS INFORMACIÓN']
# Attributes: {'href': 'https://www.eoi.es/es/volvemos-covid19'}
#
#
# TAG: <a href="https://www.eoi.es/es/becas/34714/descuentos-para-nuevos-lideres-digitales">MÁS INFORMACIÓN</a>
# URL: https://www.eoi.es/es/becas/34714/descuentos-para-nuevos-lideres-digitales
# Text: ['MÁS INFORMACIÓN']
# Attributes: {'href': 'https://www.eoi.es/es/becas/34714/descuentos-para-nuevos-lideres-digitales'}
#
#
# TAG: <a href="/es/noticias/33705/eoi-se-consolida-como-lider-en-formacion-medioambiental-en-espana">MÁS INFORMACIÓN</a>
# URL: /es/noticias/33705/eoi-se-consolida-como-lider-en-formacion-medioambiental-en-espana
# Text: ['MÁS INFORMACIÓN']
# Attributes: {'href': '/es/noticias/33705/eoi-se-consolida-como-lider-en-formacion-medioambiental-en-espana'}
#
#
# TAG: <a href="/es/noticias/32543/el-master-en-big-data-de-eoi-destaca-en-el-ranking-qs-por-su-retorno-de-inversion-un-25-superior-la-media-internacional">MÁS INFORMACIÓN</a>
# URL: /es/noticias/32543/el-master-en-big-data-de-eoi-destaca-en-el-ranking-qs-por-su-retorno-de-inversion-un-25-superior-la-media-internacional
# Text: ['MÁS INFORMACIÓN']
# Attributes: {'href': '/es/noticias/32543/el-master-en-big-data-de-eoi-destaca-en-el-ranking-qs-por-su-retorno-de-inversion-un-25-superior-la-media-internacional'}
#
#
# TAG: <a class="carousel-control-prev" data-slide="prev" href="#carousel-example-2">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# URL: #carousel-example-2
# Text: ['\n', <span aria-hidden="true" class="carousel-control-prev-icon"></span>, '\n', <span class="sr-only">Previous</span>, '\n']
# Attributes: {'class': ['carousel-control-prev'], 'href': '#carousel-example-2', 'data-slide': 'prev'}
#
#
# TAG: <a class="carousel-control-next" data-slide="next" href="#carousel-example-2">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# URL: #carousel-example-2
# Text: ['\n', <span aria-hidden="true" class="carousel-control-next-icon"></span>, '\n', <span class="sr-only">Next</span>, '\n']
# Attributes: {'class': ['carousel-control-next'], 'href': '#carousel-example-2', 'data-slide': 'next'}
#
#
# TAG: <a aria-label="Encontrar mi programa" href="/programas/programas-executive" title="Encontrar mi programa">Encontrar mi programa</a>
# URL: /programas/programas-executive
# Text: ['Encontrar mi programa']
# Attributes: {'href': '/programas/programas-executive', 'aria-label': 'Encontrar mi programa', 'title': 'Encontrar mi programa'}
#
#
# TAG: <a href="/programas/mbas-masters">Encontrar mi programa</a>
# URL: /programas/mbas-masters
# Text: ['Encontrar mi programa']
# Attributes: {'href': '/programas/mbas-masters'}
#
#
# TAG: <a href="https://www.eoi.es/es/digital-learning">Encontrar mi programa</a>
# URL: https://www.eoi.es/es/digital-learning
# Text: ['Encontrar mi programa']
# Attributes: {'href': 'https://www.eoi.es/es/digital-learning'}
#
#
# TAG: <a class="card-block-link" href="/empresas">
# <div class="card__image card-block__field-card-image"> <img alt="Emprendimiento y empleo joven" height="185" src="/sites/default/files/styles/custom_723_x_185/public/2019-10/espacios_coworking_633x220_2.jpg?itok=ttVX-hS2" typeof="foaf:Image" width="723">
# </img></div>
# <div class="card__body card-block__body"><h1><span style="font-size: 22px;">EMPRENDIMIENTO Y EMPLEO JOVEN</span></h1>
# <p><span style="font-size:14px;">Espacios de Coworking y Cursos Especializados</span></p>
# </div>
# </a>
# URL: /empresas
# Text: ['\n', <div class="card__image card-block__field-card-image"> <img alt="Emprendimiento y empleo joven" height="185" src="/sites/default/files/styles/custom_723_x_185/public/2019-10/espacios_coworking_633x220_2.jpg?itok=ttVX-hS2" typeof="foaf:Image" width="723">
# </img></div>, '\n', <div class="card__body card-block__body"><h1><span style="font-size: 22px;">EMPRENDIMIENTO Y EMPLEO JOVEN</span></h1>
# <p><span style="font-size:14px;">Espacios de Coworking y Cursos Especializados</span></p>
# </div>, '\n']
# Attributes: {'class': ['card-block-link'], 'href': '/empresas'}
#
#
# TAG: <a class="card-block-link" href="/es/conocenos/internacional">
# <div class="card__image card-block__field-card-image"> <img alt="Internacional" height="200" src="/sites/default/files/styles/custom_300_x_200/public/2019-10/internacional_sin_texto_0.png?itok=JoHmebnw" typeof="foaf:Image" width="300">
# </img></div>
# <div class="card__body card-block__body"><h1><span style="font-size:22px;">INTERNACIONAL</span></h1>
# <p><span style="font-size: 14px;">Una red de socios en todo el mundo</span></p>
# </div>
# </a>
# URL: /es/conocenos/internacional
# Text: ['\n', <div class="card__image card-block__field-card-image"> <img alt="Internacional" height="200" src="/sites/default/files/styles/custom_300_x_200/public/2019-10/internacional_sin_texto_0.png?itok=JoHmebnw" typeof="foaf:Image" width="300">
# </img></div>, '\n', <div class="card__body card-block__body"><h1><span style="font-size:22px;">INTERNACIONAL</span></h1>
# <p><span style="font-size: 14px;">Una red de socios en todo el mundo</span></p>
# </div>, '\n']
# Attributes: {'class': ['card-block-link'], 'href': '/es/conocenos/internacional'}
#
#
# TAG: <a class="card-block-link" href="/savia">
# <div class="card__image card-block__field-card-image"> <img alt="Savia" height="200" src="/sites/default/files/styles/custom_300_x_200/public/2019-10/savia_cerebro_0.png?itok=RviPHW4G" typeof="foaf:Image" width="300">
# </img></div>
# <div class="card__body card-block__body"><h1><span style="font-size:22px;">SAVIA</span></h1>
# <p><span style="font-size:14px;">Consulta el conocimiento en abierto de EOI</span></p>
# </div>
# </a>
# URL: /savia
# Text: ['\n', <div class="card__image card-block__field-card-image"> <img alt="Savia" height="200" src="/sites/default/files/styles/custom_300_x_200/public/2019-10/savia_cerebro_0.png?itok=RviPHW4G" typeof="foaf:Image" width="300">
# </img></div>, '\n', <div class="card__body card-block__body"><h1><span style="font-size:22px;">SAVIA</span></h1>
# <p><span style="font-size:14px;">Consulta el conocimiento en abierto de EOI</span></p>
# </div>, '\n']
# Attributes: {'class': ['card-block-link'], 'href': '/savia'}
#
#
# TAG: <a class="card-block-link" href="/es/conocenos/historia">
# <div class="card__image card-block__field-card-image"> <img alt="Institución" height="185" src="/sites/default/files/styles/custom_723_x_185/public/2019-10/institucion_1_2.png?itok=DjeC1i9U" typeof="foaf:Image" width="723">
# </img></div>
# <div class="card__body card-block__body"><h1><span style="font-size:22px;">INSTITUCIÓN</span></h1>
# <p><span style="font-size:14px;">Formando líderes desde 1955</span></p>
# </div>
# </a>
# URL: /es/conocenos/historia
# Text: ['\n', <div class="card__image card-block__field-card-image"> <img alt="Institución" height="185" src="/sites/default/files/styles/custom_723_x_185/public/2019-10/institucion_1_2.png?itok=DjeC1i9U" typeof="foaf:Image" width="723">
# </img></div>, '\n', <div class="card__body card-block__body"><h1><span style="font-size:22px;">INSTITUCIÓN</span></h1>
# <p><span style="font-size:14px;">Formando líderes desde 1955</span></p>
# </div>, '\n']
# Attributes: {'class': ['card-block-link'], 'href': '/es/conocenos/historia'}
#
#
# TAG: <a href="https://www.eoi.es/es/clubeoi/eventos/35721/taller-nuestro-cv-quienes-somos-y-que-aportamos-club-eoi-aforo-completo">Taller “Nuestro CV: quiénes somos y qué aportamos” (Club EOI) [AFORO COMPLETO]</a>
# URL: https://www.eoi.es/es/clubeoi/eventos/35721/taller-nuestro-cv-quienes-somos-y-que-aportamos-club-eoi-aforo-completo
# Text: ['Taller “Nuestro CV: quiénes somos y qué aportamos” (Club EOI) [AFORO COMPLETO]']
# Attributes: {'href': 'https://www.eoi.es/es/clubeoi/eventos/35721/taller-nuestro-cv-quienes-somos-y-que-aportamos-club-eoi-aforo-completo'}
#
#
# TAG: <a href="https://www.eoi.es/es/eventos/35792/taller-storytelling-para-emprendedores-coworking-malaga">Taller “Storytelling para emprendedores” (Coworking Málaga)</a>
# URL: https://www.eoi.es/es/eventos/35792/taller-storytelling-para-emprendedores-coworking-malaga
# Text: ['Taller “Storytelling para emprendedores” (Coworking Málaga)']
# Attributes: {'href': 'https://www.eoi.es/es/eventos/35792/taller-storytelling-para-emprendedores-coworking-malaga'}
#
#
# TAG: <a href="https://www.eoi.es/es/eventos/35773/webinar-tomar-decisiones-basadas-en-datos-aplicaciones-de-talent-analytics">Webinar "Tomar decisiones basadas en datos. Aplicaciones de Talent Analytics"</a>
# URL: https://www.eoi.es/es/eventos/35773/webinar-tomar-decisiones-basadas-en-datos-aplicaciones-de-talent-analytics
# Text: ['Webinar "Tomar decisiones basadas en datos. Aplicaciones de Talent Analytics"']
# Attributes: {'href': 'https://www.eoi.es/es/eventos/35773/webinar-tomar-decisiones-basadas-en-datos-aplicaciones-de-talent-analytics'}
#
#
# TAG: <a href="https://www.eoi.es/es/clubeoi/eventos/35725/taller-gestion-de-la-incertidumbre-traves-de-mindfulness-online">Taller "Gestión de la Incertidumbre a través de Mindfulness" (Online)</a>
# URL: https://www.eoi.es/es/clubeoi/eventos/35725/taller-gestion-de-la-incertidumbre-traves-de-mindfulness-online
# Text: ['Taller "Gestión de la Incertidumbre a través de Mindfulness" (Online)']
# Attributes: {'href': 'https://www.eoi.es/es/clubeoi/eventos/35725/taller-gestion-de-la-incertidumbre-traves-de-mindfulness-online'}
#
#
# TAG: <a href="https://www.eoi.es/es/eventos/35763/webinar-la-revolucion-de-iot-y-5g">Webinar “La revolución de IoT y 5G”</a>
# URL: https://www.eoi.es/es/eventos/35763/webinar-la-revolucion-de-iot-y-5g
# Text: ['Webinar “La revolución de IoT y 5G”']
# Attributes: {'href': 'https://www.eoi.es/es/eventos/35763/webinar-la-revolucion-de-iot-y-5g'}
#
#
# TAG: <a class="carousel-control-prev" data-slide="prev" href="#theCarousel_317833015">
# <span class="fa fa-chevron-left fa-lg" style="color:#82b927;"></span>
# <span class="sr-only">Previous</span>
# </a>
# URL: #theCarousel_317833015
# Text: ['\n', <span class="fa fa-chevron-left fa-lg" style="color:#82b927;"></span>, '\n', <span class="sr-only">Previous</span>, '\n']
# Attributes: {'class': ['carousel-control-prev'], 'href': '#theCarousel_317833015', 'data-slide': 'prev'}
#
#
# TAG: <a class="carousel-control-next" data-slide="next" href="#theCarousel_317833015">
# <span class="fa fa-chevron-right fa-lg" style="color:#82b927;"></span>
# <span class="sr-only">Next</span>
# </a>
# URL: #theCarousel_317833015
# Text: ['\n', <span class="fa fa-chevron-right fa-lg" style="color:#82b927;"></span>, '\n', <span class="sr-only">Next</span>, '\n']
# Attributes: {'class': ['carousel-control-next'], 'href': '#theCarousel_317833015', 'data-slide': 'next'}
#
#
# TAG: <a class="button" href="https://www.eoi.es/actualidad">Ver toda la agenda</a>
# URL: https://www.eoi.es/actualidad
# Text: ['Ver toda la agenda']
# Attributes: {'href': 'https://www.eoi.es/actualidad', 'class': ['button']}
#
#
# TAG: <a aria-label="Ver el programa" href="/es/cursos/35505/programa-ejecutivo-en-smart-energy-madrid" title="Ver el programa">Ver el programa</a>
# URL: /es/cursos/35505/programa-ejecutivo-en-smart-energy-madrid
# Text: ['Ver el programa']
# Attributes: {'href': '/es/cursos/35505/programa-ejecutivo-en-smart-energy-madrid', 'aria-label': 'Ver el programa', 'title': 'Ver el programa'}
#
#
# TAG: <a aria-label="Ver el programa" href="/es/cursos/33289/programa-de-desarrollo-para-la-direccion-mujeres-con-alto-potencial-madrid" title="Ver el programa">Ver el programa</a>
# URL: /es/cursos/33289/programa-de-desarrollo-para-la-direccion-mujeres-con-alto-potencial-madrid
# Text: ['Ver el programa']
# Attributes: {'href': '/es/cursos/33289/programa-de-desarrollo-para-la-direccion-mujeres-con-alto-potencial-madrid', 'aria-label': 'Ver el programa', 'title': 'Ver el programa'}
#
#
# TAG: <a aria-label="Ver el programa" href="/es/cursos/16532/executive-mba-online" title="Ver el programa">Ver el programa</a>
# URL: /es/cursos/16532/executive-mba-online
# Text: ['Ver el programa']
# Attributes: {'href': '/es/cursos/16532/executive-mba-online', 'aria-label': 'Ver el programa', 'title': 'Ver el programa'}
#
#
# TAG: <a href="/programas/admisiones"><span style="font-size:14px;"></span><span style="font-size:14px;">SOLICITA ADMISIÓN</span><span style="font-size:14px;"></span></a>
# URL: /programas/admisiones
# Text: [<span style="font-size:14px;"></span>, <span style="font-size:14px;">SOLICITA ADMISIÓN</span>, <span style="font-size:14px;"></span>]
# Attributes: {'href': '/programas/admisiones'}
#
#
# TAG: <a href="/programas/becas-y-ayudas"><span style="font-size:14px;"></span><span style="font-size:14px;">CONSULTA LAS CONVOCATORIAS</span><span style="font-size:14px;"></span></a>
# URL: /programas/becas-y-ayudas
# Text: [<span style="font-size:14px;"></span>, <span style="font-size:14px;">CONSULTA LAS CONVOCATORIAS</span>, <span style="font-size:14px;"></span>]
# Attributes: {'href': '/programas/becas-y-ayudas'}
#
#
# TAG: <a href="/conocenos/colegios-mayores"><span style="font-size:14px;"></span><span style="font-size:14px;">VER LOS ALOJAMIENTOS</span><span style="font-size:14px;"></span></a>
# URL: /conocenos/colegios-mayores
# Text: [<span style="font-size:14px;"></span>, <span style="font-size:14px;">VER LOS ALOJAMIENTOS</span>, <span style="font-size:14px;"></span>]
# Attributes: {'href': '/conocenos/colegios-mayores'}
#
#
# TAG: <a href="/es/conocenos/sedes">Conoce nuestros campus</a>
# URL: /es/conocenos/sedes
# Text: ['Conoce nuestros campus']
# Attributes: {'href': '/es/conocenos/sedes'}
#
#
# TAG: <a class="image-block-link" href="https://www.eoi.es/sites/default/files/inline-files/Certificado_9001.pdf">
# <div class="image-block-image"> <img alt="ISO 9001" height="134" src="/sites/default/files/styles/medium/public/2020-03/ISO_9001_REC.png?itok=ZDW8odPi" typeof="foaf:Image" width="220">
# </img></div>
# </a>
# URL: https://www.eoi.es/sites/default/files/inline-files/Certificado_9001.pdf
# Text: ['\n', <div class="image-block-image"> <img alt="ISO 9001" height="134" src="/sites/default/files/styles/medium/public/2020-03/ISO_9001_REC.png?itok=ZDW8odPi" typeof="foaf:Image" width="220">
# </img></div>, '\n']
# Attributes: {'class': ['image-block-link'], 'href': 'https://www.eoi.es/sites/default/files/inline-files/Certificado_9001.pdf'}
#
#
# TAG: <a class="banner-image-link" href="https://www.eoi.es/sites/default/files/inline-files/Certificado_14001.pdf">
# <div class="banner-image-image">
# <img alt="ISO 14001" height="140" src="/sites/default/files/2020-08/ISO_14001_REC_v2_220X140.png" typeof="foaf:Image" width="220">
# <div class="banner-image-body">
# </div>
# </img></div>
# </a>
# URL: https://www.eoi.es/sites/default/files/inline-files/Certificado_14001.pdf
# Text: ['\n', <div class="banner-image-image">
# <img alt="ISO 14001" height="140" src="/sites/default/files/2020-08/ISO_14001_REC_v2_220X140.png" typeof="foaf:Image" width="220">
# <div class="banner-image-body">
# </div>
# </img></div>, '\n']
# Attributes: {'class': ['banner-image-link'], 'href': 'https://www.eoi.es/sites/default/files/inline-files/Certificado_14001.pdf'}
#
#
# TAG: <a class="image-block-link" href="https://www.eoi.es/sites/default/files/inline-files/Certificado_45001.pdf">
# <div class="image-block-image"> <img alt="ISO 45001" height="140" src="/sites/default/files/styles/medium/public/2020-03/45001_REC.png?itok=-yxYrw8D" typeof="foaf:Image" width="220">
# </img></div>
# </a>
# URL: https://www.eoi.es/sites/default/files/inline-files/Certificado_45001.pdf
# Text: ['\n', <div class="image-block-image"> <img alt="ISO 45001" height="140" src="/sites/default/files/styles/medium/public/2020-03/45001_REC.png?itok=-yxYrw8D" typeof="foaf:Image" width="220">
# </img></div>, '\n']
# Attributes: {'class': ['image-block-link'], 'href': 'https://www.eoi.es/sites/default/files/inline-files/Certificado_45001.pdf'}
#
#
# TAG: <a aria-label="Programas" href="/programas" title="Programas">Programas</a>
# URL: /programas
# Text: ['Programas']
# Attributes: {'href': '/programas', 'aria-label': 'Programas', 'title': 'Programas'}
#
#
# TAG: <a aria-label="MBAs &amp; Masters" href="/mbas-masters" title="MBAs &amp; Masters">MBAs &amp; Masters</a>
# URL: /mbas-masters
# Text: ['MBAs & Masters']
# Attributes: {'href': '/mbas-masters', 'aria-label': 'MBAs & Masters', 'title': 'MBAs & Masters'}
#
#
# TAG: <a aria-label="Programas Ejecutivos" href="/programas/programas-ejecutivos" title="Programas Ejecutivos">Programas Ejecutivos</a>
# URL: /programas/programas-ejecutivos
# Text: ['Programas Ejecutivos']
# Attributes: {'href': '/programas/programas-ejecutivos', 'aria-label': 'Programas Ejecutivos', 'title': 'Programas Ejecutivos'}
#
#
# TAG: <a aria-label="Programas Enfocados" href="/programas/programas-enfocados" title="Programas Enfocados">Programas Enfocados</a>
# URL: /programas/programas-enfocados
# Text: ['Programas Enfocados']
# Attributes: {'href': '/programas/programas-enfocados', 'aria-label': 'Programas Enfocados', 'title': 'Programas Enfocados'}
#
#
# TAG: <a aria-label="Admisiones" href="/admisiones" title="Admisiones">Admisiones</a>
# URL: /admisiones
# Text: ['Admisiones']
# Attributes: {'href': '/admisiones', 'aria-label': 'Admisiones', 'title': 'Admisiones'}
#
#
# TAG: <a aria-label="Cursos, Talleres y Seminarios" href="/programas/cursos-talleres-seminarios" title="Cursos, Talleres y Seminarios">Cursos, Talleres y Seminarios</a>
# URL: /programas/cursos-talleres-seminarios
# Text: ['Cursos, Talleres y Seminarios']
# Attributes: {'href': '/programas/cursos-talleres-seminarios', 'aria-label': 'Cursos, Talleres y Seminarios', 'title': 'Cursos, Talleres y Seminarios'}
#
#
# TAG: <a aria-label="Becas y ayudas" href="/becas-y-ayudas" title="Becas y ayudas">Becas y ayudas</a>
# URL: /becas-y-ayudas
# Text: ['Becas y ayudas']
# Attributes: {'href': '/becas-y-ayudas', 'aria-label': 'Becas y ayudas', 'title': 'Becas y ayudas'}
#
#
# TAG: <a aria-label="Metodología" href="/es/metodologia" title="Metodología">Metodología</a>
# URL: /es/metodologia
# Text: ['Metodología']
# Attributes: {'href': '/es/metodologia', 'aria-label': 'Metodología', 'title': 'Metodología'}
#
#
# TAG: <a href="/programas/programas-enfocados">Programas Enfocados</a>
# URL: /programas/programas-enfocados
# Text: ['Programas Enfocados']
# Attributes: {'href': '/programas/programas-enfocados'}
#
#
# TAG: <a href="/empresas">Empresas</a>
# URL: /empresas
# Text: ['Empresas']
# Attributes: {'href': '/empresas'}
#
#
# TAG: <a aria-label="In company" href="/in-company" title="In company">In company</a>
# URL: /in-company
# Text: ['In company']
# Attributes: {'href': '/in-company', 'aria-label': 'In company', 'title': 'In company'}
#
#
# TAG: <a aria-label="Pymes" href="/pymes" title="Pymes">Pymes</a>
# URL: /pymes
# Text: ['Pymes']
# Attributes: {'href': '/pymes', 'aria-label': 'Pymes', 'title': 'Pymes'}
#
#
# TAG: <a aria-label="Emprendimiento" href="/es/emprendimiento" title="Emprendimiento">Emprendimiento</a>
# URL: /es/emprendimiento
# Text: ['Emprendimiento']
# Attributes: {'href': '/es/emprendimiento', 'aria-label': 'Emprendimiento', 'title': 'Emprendimiento'}
#
#
# TAG: <a aria-label="Acuerdos" href="/acuerdos" title="Acuerdos">Acuerdos</a>
# URL: /acuerdos
# Text: ['Acuerdos']
# Attributes: {'href': '/acuerdos', 'aria-label': 'Acuerdos', 'title': 'Acuerdos'}
#
#
# TAG: <a aria-label="Investigación" href="/investigacion" title="Investigación">Investigación</a>
# URL: /investigacion
# Text: ['Investigación']
# Attributes: {'href': '/investigacion', 'aria-label': 'Investigación', 'title': 'Investigación'}
#
#
# TAG: <a aria-label="Publicaciones" href="/publicaciones" title="Publicaciones">Publicaciones</a>
# URL: /publicaciones
# Text: ['Publicaciones']
# Attributes: {'href': '/publicaciones', 'aria-label': 'Publicaciones', 'title': 'Publicaciones'}
#
#
# TAG: <a aria-label="Repositorio Savia" href="/repositorio-savia" title="Repositorio Savia">Repositorio Savia</a>
# URL: /repositorio-savia
# Text: ['Repositorio Savia']
# Attributes: {'href': '/repositorio-savia', 'aria-label': 'Repositorio Savia', 'title': 'Repositorio Savia'}
#
#
# TAG: <a aria-label="Biblioteca" href="/es/biblioteca" title="Biblioteca">Biblioteca</a>
# URL: /es/biblioteca
# Text: ['Biblioteca']
# Attributes: {'href': '/es/biblioteca', 'aria-label': 'Biblioteca', 'title': 'Biblioteca'}
#
#
# TAG: <a aria-label="Cátedra EOI OEPM" href="/catedra-eoi-oepm" title="Cátedra EOI OEPM">Cátedra EOI OEPM</a>
# URL: /catedra-eoi-oepm
# Text: ['Cátedra EOI OEPM']
# Attributes: {'href': '/catedra-eoi-oepm', 'aria-label': 'Cátedra EOI OEPM', 'title': 'Cátedra EOI OEPM'}
#
#
# TAG: <a aria-label="OPTI" href="/opti" title="OPTI">OPTI</a>
# URL: /opti
# Text: ['OPTI']
# Attributes: {'href': '/opti', 'aria-label': 'OPTI', 'title': 'OPTI'}
#
#
# TAG: <a href="/es/alumni">Alumni</a>
# URL: /es/alumni
# Text: ['Alumni']
# Attributes: {'href': '/es/alumni'}
#
#
# TAG: <a aria-label="Prácticas" href="/es/alumni/alumni-practicas" title="Prácticas">Prácticas</a>
# URL: /es/alumni/alumni-practicas
# Text: ['Prácticas']
# Attributes: {'href': '/es/alumni/alumni-practicas', 'aria-label': 'Prácticas', 'title': 'Prácticas'}
#
#
# TAG: <a aria-label="Carreras profesionales" href="/es/alumni/carreras-profesionales" title="Carreras profesionales">Carreras profesionales</a>
# URL: /es/alumni/carreras-profesionales
# Text: ['Carreras profesionales']
# Attributes: {'href': '/es/alumni/carreras-profesionales', 'aria-label': 'Carreras profesionales', 'title': 'Carreras profesionales'}
#
#
# TAG: <a aria-label="Club EOI" href="/club-eoi" title="Club EOI">Club EOI</a>
# URL: /club-eoi
# Text: ['Club EOI']
# Attributes: {'href': '/club-eoi', 'aria-label': 'Club EOI', 'title': 'Club EOI'}
#
#
# TAG: <a aria-label="Conócenos" href="/conocenos" title="Conócenos">Conócenos</a>
# URL: /conocenos
# Text: ['Conócenos']
# Attributes: {'href': '/conocenos', 'aria-label': 'Conócenos', 'title': 'Conócenos'}
#
#
# TAG: <a href="/es/conocenos/quienes-somos">Quiénes somos</a>
# URL: /es/conocenos/quienes-somos
# Text: ['Quiénes somos']
# Attributes: {'href': '/es/conocenos/quienes-somos'}
#
#
# TAG: <a href="/es/conocenos/fundesarte">Fundesarte</a>
# URL: /es/conocenos/fundesarte
# Text: ['Fundesarte']
# Attributes: {'href': '/es/conocenos/fundesarte'}
#
#
# TAG: <a href="/es/conocenos/internacional">Internacional</a>
# URL: /es/conocenos/internacional
# Text: ['Internacional']
# Attributes: {'href': '/es/conocenos/internacional'}
#
#
# TAG: <a href="/es/conocenos/sedes">Sedes</a>
# URL: /es/conocenos/sedes
# Text: ['Sedes']
# Attributes: {'href': '/es/conocenos/sedes'}
#
#
# TAG: <a href="/es/conocenos/colegios-mayores">Colegios mayores</a>
# URL: /es/conocenos/colegios-mayores
# Text: ['Colegios mayores']
# Attributes: {'href': '/es/conocenos/colegios-mayores'}
#
#
# TAG: <a href="/es/conocenos/transparencia">Transparencia</a>
# URL: /es/conocenos/transparencia
# Text: ['Transparencia']
# Attributes: {'href': '/es/conocenos/transparencia'}
#
#
# TAG: <a aria-label="Actualidad" href="/actualidad" title="Actualidad">Actualidad</a>
# URL: /actualidad
# Text: ['Actualidad']
# Attributes: {'href': '/actualidad', 'aria-label': 'Actualidad', 'title': 'Actualidad'}
#
#
# TAG: <a aria-label="Agenda" href="/agenda" title="Agenda">Agenda</a>
# URL: /agenda
# Text: ['Agenda']
# Attributes: {'href': '/agenda', 'aria-label': 'Agenda', 'title': 'Agenda'}
#
#
# TAG: <a aria-label="Sala de prensa" href="/sala-de-prensa" title="Sala de prensa">Sala de prensa</a>
# URL: /sala-de-prensa
# Text: ['Sala de prensa']
# Attributes: {'href': '/sala-de-prensa', 'aria-label': 'Sala de prensa', 'title': 'Sala de prensa'}
#
#
# TAG: <a aria-label="Identidad corporativa" href="/identidad-corporativa" title="Identidad corporativa">Identidad corporativa</a>
# URL: /identidad-corporativa
# Text: ['Identidad corporativa']
# Attributes: {'href': '/identidad-corporativa', 'aria-label': 'Identidad corporativa', 'title': 'Identidad corporativa'}
#
#
# TAG: <a aria-label="Blogs" href="/blogs" title="Blogs">Blogs</a>
# URL: /blogs
# Text: ['Blogs']
# Attributes: {'href': '/blogs', 'aria-label': 'Blogs', 'title': 'Blogs'}
#
#
# TAG: <a aria-label="Redes sociales" href="/redes-sociales" title="Redes sociales">Redes sociales</a>
# URL: /redes-sociales
# Text: ['Redes sociales']
# Attributes: {'href': '/redes-sociales', 'aria-label': 'Redes sociales', 'title': 'Redes sociales'}
#
#
# TAG: <a aria-label="Twitter" href="https://www.twitter.com/eoi" title="Twitter">
# <span class="fa fa-twitter fa-2x"></span>
# <span class="sr-only">Links, Opens in this window</span>
# </a>
# URL: https://www.twitter.com/eoi
# Text: ['\n', <span class="fa fa-twitter fa-2x"></span>, '\n', <span class="sr-only">Links, Opens in this window</span>, '\n']
# Attributes: {'href': 'https://www.twitter.com/eoi', 'aria-label': 'Twitter', 'title': 'Twitter'}
#
#
# TAG: <a aria-label="Facebook" href="https://www.facebook.com/eoi.edu" title="Facebook">
# <span class="fa fa-facebook fa-2x"></span>
# <span class="sr-only">Links, Opens in this window</span>
# </a>
# URL: https://www.facebook.com/eoi.edu
# Text: ['\n', <span class="fa fa-facebook fa-2x"></span>, '\n', <span class="sr-only">Links, Opens in this window</span>, '\n']
# Attributes: {'href': 'https://www.facebook.com/eoi.edu', 'aria-label': 'Facebook', 'title': 'Facebook'}
#
#
# TAG: <a aria-label="Linkedin" href="https://www.linkedin.com/school/eoi/" title="Linkedin">
# <span class="fa fa-linkedin fa-2x"></span>
# <span class="sr-only">Links, Opens in this window</span>
# </a>
# URL: https://www.linkedin.com/school/eoi/
# Text: ['\n', <span class="fa fa-linkedin fa-2x"></span>, '\n', <span class="sr-only">Links, Opens in this window</span>, '\n']
# Attributes: {'href': 'https://www.linkedin.com/school/eoi/', 'aria-label': 'Linkedin', 'title': 'Linkedin'}
#
#
# TAG: <a aria-label="Youtube" href="https://www.youtube.com/user/eoimedia" title="Youtube">
# <span class="fa fa-youtube fa-2x"></span>
# <span class="sr-only">Links, Opens in this window</span>
# </a>
# URL: https://www.youtube.com/user/eoimedia
# Text: ['\n', <span class="fa fa-youtube fa-2x"></span>, '\n', <span class="sr-only">Links, Opens in this window</span>, '\n']
# Attributes: {'href': 'https://www.youtube.com/user/eoimedia', 'aria-label': 'Youtube', 'title': 'Youtube'}
#
#
# TAG: <a aria-label="Flickr" href="https://www.flickr.com/photos/eoi/" title="Flickr">
# <span class="fa fa-flickr fa-2x"></span>
# <span class="sr-only">Links, Opens in this window</span>
# </a>
# URL: https://www.flickr.com/photos/eoi/
# Text: ['\n', <span class="fa fa-flickr fa-2x"></span>, '\n', <span class="sr-only">Links, Opens in this window</span>, '\n']
# Attributes: {'href': 'https://www.flickr.com/photos/eoi/', 'aria-label': 'Flickr', 'title': 'Flickr'}
#
#
# TAG: <a aria-label="Instagram" href="https://www.instagram.com/eoischool/" title="Instagram">
# <span class="fa fa-instagram fa-2x"></span>
# <span class="sr-only">Links, Opens in this window</span>
# </a>
# URL: https://www.instagram.com/eoischool/
# Text: ['\n', <span class="fa fa-instagram fa-2x"></span>, '\n', <span class="sr-only">Links, Opens in this window</span>, '\n']
# Attributes: {'href': 'https://www.instagram.com/eoischool/', 'aria-label': 'Instagram', 'title': 'Instagram'}
#
#
# TAG: <a aria-label="Perfil de contratante" href="/es/conocenos/perfil-de-contratante" title="Perfil de contratante">Perfil de contratante</a>
# URL: /es/conocenos/perfil-de-contratante
# Text: ['Perfil de contratante']
# Attributes: {'href': '/es/conocenos/perfil-de-contratante', 'aria-label': 'Perfil de contratante', 'title': 'Perfil de contratante'}
#
#
# TAG: <a aria-label="Aviso Legal" href="/es/aviso-legal" title="Aviso Legal">Aviso Legal</a>
# URL: /es/aviso-legal
# Text: ['Aviso Legal']
# Attributes: {'href': '/es/aviso-legal', 'aria-label': 'Aviso Legal', 'title': 'Aviso Legal'}
#
#
# TAG: <a aria-label="Política de privacidad" href="/es/politica-de-privacidad" title="Política de privacidad">Política de privacidad</a>
# URL: /es/politica-de-privacidad
# Text: ['Política de privacidad']
# Attributes: {'href': '/es/politica-de-privacidad', 'aria-label': 'Política de privacidad', 'title': 'Política de privacidad'}
#
#
# TAG: <a aria-label="Política de cookies" href="/es/politica-de-cookies" title="Política de cookies">Política de cookies</a>
# URL: /es/politica-de-cookies
# Text: ['Política de cookies']
# Attributes: {'href': '/es/politica-de-cookies', 'aria-label': 'Política de cookies', 'title': 'Política de cookies'}

# %% [markdown]
# Puedes encontrar la documentación de beautifulsoup en https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# <a id="ejemplos"></a>
# ## Ejemplos de web scraping

# %% [markdown]
# ### 1. Frecuencia de las palabras de un discurso
# Vamos a obtener la frecuencia de las palabras del siguiente discurso: https://elpais.com/internacional/2018/01/31/actualidad/1517387619_036241.html

# %%
import urllib
from bs4 import BeautifulSoup

url = 'https://elpais.com/internacional/2018/01/31/actualidad/1517387619_036241.html'
html = urllib.request.urlopen(url)

soup2 = BeautifulSoup(html)

tags = soup2('p') # Extraigo las etiquetas de tipo <p>

discurso = '' # Aquí guardo el discurso, inicialmente vacío

for tag in tags:
    if (len(tag.attrs))==0:
        a = tag.contents[0] # Extrayendo el texto de la etiqueta
        discurso = discurso + a
        
# print (discurso)

contadores = dict()

discurso = (discurso.replace(',', '')
                    .replace('. ', ' ')
                    .replace('.', ' ')
                    .replace(':', '')
                    .replace('?', '')
                    .replace('(', '')
                    .replace(')', ''))

palabras = discurso.lower().split()

for palabra in palabras:
    if len(palabra)>3:
        contadores[palabra] = contadores.get(palabra, 0)+1

import pandas as pd

pd.DataFrame(list(contadores.items()), columns = ['palabra','contador']).sort_values('contador', ascending=False).head(10)
# Out:
#              palabra  contador
# 20              para        65
# 18              esta        37
# 55   estadounidenses        32
# 548         nuestros        28
# 31           nuestro        28
# 59             hemos        27
# 343          nuestra        27
# 10            unidos        27
# 127             como        26
# 9            estados        26

# %% [markdown]
# ### 2. Web Scraping de CoinMarketCap
# Extraemos el valor más reciente de Bitcoin en https://coinmarketcap.com/currencies/bitcoin/

# %%
import urllib
from bs4 import BeautifulSoup

url = 'https://coinmarketcap.com/currencies/bitcoin/'
html = urllib.request.urlopen(url)

soup = BeautifulSoup(html)

tags = soup.find_all('td', class_='priceValue___11gHJ')

float(tags[0].contents[0].replace('$','').replace(',',''))
# Out:
# 60111.03

# %% [markdown]
# ### 3. Web scraping con pandas

# %% [markdown]
# La función `read_html()` de pandas también permite extraer tablas de páginas web, devolviendo una lista de dataframes con todas las tablas que existan.
# Por ejemplo, vamos a hacer scraping de la siguiente tabla: http://www.fdic.gov/bank/individual/failed/banklist.html
#
# Es necesario instalar la librería `lxml`: `conda install -c conda-forge lxml`

# %%
import pandas as pd
url = 'https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/'

tablas = pd.read_html(url)
tablas[0]
# Out:
#                              Bank Name               City State   Cert  \
# 0                    Almena State Bank             Almena    KS  15426
# 1           First City Bank of Florida  Fort Walton Beach    FL  16748
# 2                 The First State Bank      Barboursville    WV  14361
# 3                   Ericson State Bank            Ericson    NE  18265
# 4     City National Bank of New Jersey             Newark    NJ  21111
# ..                                 ...                ...   ...    ...
# 558                 Superior Bank, FSB           Hinsdale    IL  32646
# 559                Malta National Bank              Malta    OH   6629
# 560    First Alliance Bank & Trust Co.         Manchester    NH  34264
# 561  National State Bank of Metropolis         Metropolis    IL   3815
# 562                   Bank of Honolulu           Honolulu    HI  21029
#
#                    Acquiring Institution       Closing Date
# 0                            Equity Bank   October 23, 2020
# 1              United Fidelity Bank, fsb   October 16, 2020
# 2                         MVB Bank, Inc.      April 3, 2020
# 3             Farmers and Merchants Bank  February 14, 2020
# 4                        Industrial Bank   November 1, 2019
# ..                                   ...                ...
# 558                Superior Federal, FSB      July 27, 2001
# 559                    North Valley Bank        May 3, 2001
# 560  Southern New Hampshire Bank & Trust   February 2, 2001
# 561              Banterra Bank of Marion  December 14, 2000
# 562                   Bank of the Orient   October 13, 2000
#
# [563 rows x 6 columns]
